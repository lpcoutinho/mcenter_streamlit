# %% [markdown]
# ## Populando a tabela de códigos

# %%
import os
import time
from pandas import json_normalize
import psycopg2
from psycopg2 import sql

import pandas as pd
from dotenv import load_dotenv

load_dotenv()

access_token = os.getenv("ACCESS_TOKEN")
HOST = os.getenv("HOST")
POSTGRES_DB = os.getenv("POSTGRES_DB")
POSTGRES_USER = os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")


# configuarações de conexão com o banco de dados
db_config = {
    "host": HOST,
    "database": POSTGRES_DB,
    "user": POSTGRES_USER,
    "password": POSTGRES_PASSWORD,
}

# %%
# Carregando dados do Google Sheets
sheet_id = "1bKChKN304n76zBkZTfBxXrbSvSf2ZC4oXap940x8MNc"
sheet_name = "Relação Full x Tiny"
url = f"https://docs.google.com/spreadsheet/ccc?key={sheet_id}&output=xlsx"

# features
col1 = "Código ML"
col2 = "ID do anúncio"
col3 = "ID Tiny"
col4 = "SKU"
col5 = "SKU Tiny"

df_codes = pd.read_excel(
    url, sheet_name=sheet_name, usecols=[col1, col2, col3, col4, col5]
)

col = {
    "Código ML": "ml_inventory_id",
    "ID do anúncio": "ml_code",
    "ID Tiny": "tiny_id",
    "SKU": "ml_sku",
    "SKU Tiny": "tiny_sku",
}

df_codes.rename(columns=col, inplace=True)

df_codes.shape
# Out:
# (877, 5)

# %%
df_codes.head(3)
# Out:
#       ml_sku ml_inventory_id     ml_code       tiny_sku    tiny_id
# 0  FULLNI5BM       DSGP06967  1992567302  7897937421021  735947207
# 1  FULLNI7AM       DSGP06979  1992567302  7897937421007  747848159
# 2  FULLNI5AM       JJSZ06277  1992567302  7897937421014  698412654

# %% [markdown]
# ### Adicionando prefixo MLB na coluna 'ml_code'

# %%
df_codes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 877 entries, 0 to 876
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ml_sku           875 non-null    object
#  1   ml_inventory_id  795 non-null    object
#  2   ml_code          877 non-null    int64
#  3   tiny_sku         877 non-null    object
#  4   tiny_id          877 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 34.4+ KB

# %%
df_codes["ml_code"] = df_codes["ml_code"].apply(str)
df_codes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 877 entries, 0 to 876
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ml_sku           875 non-null    object
#  1   ml_inventory_id  795 non-null    object
#  2   ml_code          877 non-null    object
#  3   tiny_sku         877 non-null    object
#  4   tiny_id          877 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 34.4+ KB

# %%
df_codes["ml_code"] = "MLB" + df_codes["ml_code"]
df_codes.head(1)
# Out:
#       ml_sku ml_inventory_id        ml_code       tiny_sku    tiny_id
# 0  FULLNI5BM       DSGP06967  MLB1992567302  7897937421021  735947207

# %%
df_codes.shape
# Out:
# (877, 5)

# %% [markdown]
# ### Tratando dados duplicados

# %%
duplicates = df_codes.duplicated()
n_dup = duplicates.sum()

print(f"Número de duplicatas: {n_dup}")

duplicates = df_codes[df_codes.duplicated(keep=False)]

duplicates
# Out:
# Número de duplicatas: 7
#                     ml_sku ml_inventory_id        ml_code       tiny_sku  \
# 519       FULLORIONSPX15HH       WXUT79339  MLB1512798100  7898608740991
# 520       FULLORIONSP16CHH       TDFP80328  MLB1512860650  7898608741899
# 521        FULLORIONSP18CH       OFYI79568  MLB1509021649  7898608741905
# 607             FULLC4RH16       IYUQ71257  MLB2192258271  7891088100057
# 679   FULLTAGIMA27KCOMCAPA       DUCB06017  MLB1557290709  7898563978156
# 680   FULLTAGIMA27KCOMCAPA       DUCB06017  MLB1557290709  7898563978156
# 681  FULLTAGIMA27KCOMCAPAC       SSBF06040  MLB1557306058  7898563978156
# 682  FULLTAGIMA27KCOMCAPAC       SSBF06040  MLB1557306058  7898563978156
# 714         CTX3000SIMPLES       KVWJ40778  MLB1233445054  4971850349099
# 718             FULLC4RH16       IYUQ71257  MLB2192258271  7891088100057
# 795         CTX3000SIMPLES       KVWJ40778  MLB1233445054  4971850349099
# 797        FULLORIONSP18CH       OFYI79568  MLB1509021649  7898608741905
# 798       FULLORIONSPX15HH       WXUT79339  MLB1512798100  7898608740991
# 799       FULLORIONSP16CHH       TDFP80328  MLB1512860650  7898608741899
#
#        tiny_id
# 519  681951269
# 520  561967156
# 521  561968045
# 607  737198870
# 679  512617044
# 680  512617044
# 681  512617044
# 682  512617044
# 714  506979980
# 718  737198870
# 795  506979980
# 797  561968045
# 798  681951269
# 799  561967156

# %%
df_codes = df_codes.drop_duplicates()
df_codes.shape
# Out:
# (870, 5)

# %%
df_codes.head(3)
# Out:
#       ml_sku ml_inventory_id        ml_code       tiny_sku    tiny_id
# 0  FULLNI5BM       DSGP06967  MLB1992567302  7897937421021  735947207
# 1  FULLNI7AM       DSGP06979  MLB1992567302  7897937421007  747848159
# 2  FULLNI5AM       JJSZ06277  MLB1992567302  7897937421014  698412654

# %%
## Removendo NaN da coluna de ml_inventory_id

df_codes = df_codes.dropna()
df_codes.shape
# Out:
# (786, 5)

# %%
df_ml_codes = df_codes[["ml_code", "ml_sku", "ml_inventory_id"]]
df_ml_codes
# Out:
#            ml_code               ml_sku ml_inventory_id
# 0    MLB1992567302            FULLNI5BM       DSGP06967
# 1    MLB1992567302            FULLNI7AM       DSGP06979
# 2    MLB1992567302            FULLNI5AM       JJSZ06277
# 3    MLB2606294854  FULLVANDOREN2CR1015       DGCL82617
# 4    MLB2606294854   FULLVANDOREN2CR102       GCYF86172
# ..             ...                  ...             ...
# 834   MLB949788598        P10LNINJA10FT       ERIM51807
# 835   MLB950297972         LWNINJA15FT1       TDFV51283
# 873  MLB1363602423                7643D       OYUK51882
# 874  MLB2004836143      FULLBASSOVTSL52       BLHH53768
# 876  MLB2184288874   FULLLIVERPOOLNI5AM       RKCI54992
#
# [786 rows x 3 columns]

# %%
df_ml_codes = df_ml_codes.drop_duplicates()
df_ml_codes.shape
# Out:
# (633, 3)

# %% [markdown]
# ## Populando tabela tiny_ml_codes no DB

# %%
# Ela contém a relação entre tiny_id e inventory_id do ML
# e não permite pares de valores duplicados entre (ml_inventory_id, tiny_id)

conn = psycopg2.connect(**db_config)

cursor = conn.cursor()

for index, row in df_ml_codes.iterrows():
    insert_query = sql.SQL(
        "INSERT INTO ml_codes (ml_inventory_id, ml_code, ml_sku) VALUES (%s, %s, %s)"
    )
    cursor.execute(
        insert_query, (row["ml_inventory_id"], row["ml_code"], row["ml_sku"])
    )

conn.commit()

# Feche o cursor e a conexão
cursor.close()
conn.close()
print("Dados inseridos com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# c:\Users\couti\projetos\api_musical\Notebooks\populando_tabela_codigos.ipynb Cell 18 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/couti/projetos/api_musical/Notebooks/populando_tabela_codigos.ipynb#X41sZmlsZQ%3D%3D?line=7'>8</a> for index, row in df_ml_codes.iterrows():
#       <a href='vscode-notebook-cell:/c%3A/Users/couti/projetos/api_musical/Notebooks/populando_tabela_codigos.ipynb#X41sZmlsZQ%3D%3D?line=8'>9</a>     insert_query = sql.SQL("INSERT INTO ml_codes (ml_inventory_id, ml_code, ml_sku) VALUES (%s, %s, %s)")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/couti/projetos/api_musical/Notebooks/populando_tabela_codigos.ipynb#X41sZmlsZQ%3D%3D?line=9'>10</a>     cursor.execute(insert_query, (row['ml_inventory_id'], row['ml_code'], row['ml_sku']))
#      <a href='vscode-notebook-cell:/c%3A/Users/couti/projetos/api_musical/Notebooks/populando_tabela_codigos.ipynb#X41sZmlsZQ%3D%3D?line=11'>12</a> conn.commit()
#      <a href='vscode-notebook-cell:/c%3A/Users/couti/projetos/api_musical/Notebooks/populando_tabela_codigos.ipynb#X41sZmlsZQ%3D%3D?line=13'>14</a> # Feche o cursor e a conexão
#
# UniqueViolation: duplicate key value violates unique constraint "ml_codes_pkey"
# DETAIL:  Key (ml_inventory_id)=(NQUG25995) already exists.

# %%
id = "NQUG25995"
x = df_ml_codes[df_ml_codes["ml_inventory_id"] == id]
x
# Out:
#            ml_code         ml_sku ml_inventory_id
# 86   MLB1407949289  FULLMAPEXH600       NQUG25995
# 162  MLB1459771919  FULLMOOERM018       NQUG25995

# %%
id = "NQUG25995"
x = df_ml_codes[df_ml_codes["ml_inventory_id"] == id]
x
# Out:
#            ml_code         ml_sku ml_inventory_id
# 86   MLB1407949289  FULLMAPEXH600       NQUG25995
# 162  MLB1459771919  FULLMOOERM018       NQUG25995

# %%
# Verificar duplicatas apenas na coluna 'ml_inventory_id'
dup = df_ml_codes[df_ml_codes["ml_inventory_id"].duplicated()]

# Exibir os valores duplicados na coluna 'ml_inventory_id'
print("Valores Duplicados na coluna 'ml_inventory_id':")
dup.to_excel("dados_duplicados.xlsx")
# Out:
# Valores Duplicados na coluna 'ml_inventory_id':

# %%
valores_unicos_duplicatas = dup[
    dup.duplicated(subset=["ml_inventory_id"], keep=False)
].drop_duplicates(subset=["ml_inventory_id"])
valores_unicos_duplicatas
# Out:
#                                ml_sku ml_inventory_id        ml_code  \
# 442                         FULLKIT01       JDTL81315  MLB1813530858
# 446                         FULLKIT01       FTGG16520  MLB1814087324
# 450              FULLGIANNINICS14EPNS       ZDLT16176  MLB1814290902
# 466                         FULLKIT02       KKOU90189  MLB1937452277
# 474                      FULLKITPPPCA       WQLG77218  MLB1942106803
# 478                          FULLKIT1       DMTU81740  MLB1943181299
# 483                          FULLKIT3       KMCE82136  MLB1943185413
# 488                          FULLKIT2       FSNB76403  MLB1943185424
# 493                     FULLKITCACPPP       ITDN80392  MLB1945629366
# 509                         FULLKIT03       ZEWV91930  MLB1976555976
# 513               FULLBASSONYPER07KIT       NKRN92702  MLB1977127000
# 517                 FULLBASSOCLA01KIT       JAOF95919  MLB1979420955
# 525                 FULLBASSOCLA04KIT       AOLT03050  MLB1991139259
# 543      FULLLIVERPOOLNI1X(5A,5B,7A)M       TNXB03680  MLB1992889189
# 548                 FULLBASSOCLA03KIT       JKBQ98755  MLB1993044887
# 554                 FULLBASSOCLA05KIT       IYUQ03362  MLB2000350479
# 559                 FULLBASSOCLA09KIT       QRSL03944  MLB2000967077
# 563                 FULLBASSOCLA13KIT       WEPI04061  MLB2000969658
# 569                 FULLBASSOCLA14KIT       PNZZ04589  MLB2001019290
# 574                 FULLBASSOCLA25KIT       YZGH03888  MLB2001037689
# 579                 FULLBASSOCLA26KIT       THQG04019  MLB2001059333
# 583     FULLBASSOCLA100JESUSMARROMKIT       HKMH99637  MLB2001098672
# 588   FULLBASSOCLAPEIXEJESUSMARROMKIT       YRHK04781  MLB2001108489
# 594    FULLBASSOCLAPEIXEJESUSPRETOKIT       JDOJ98857  MLB2001122166
# 598  FULLBASSOCLACRISTOSALVAMARROMKIT       VAJM34569  MLB2001139731
# 603   FULLBASSOCLACRISTOSALVAPRETOKIT       NTFP39349  MLB2001169495
# 610      FULLBASSOCLA100JESUSPRETOKIT       ZJTW10331  MLB2001229531
# 614                 FULLBASSOSF106KIT       QCVC39144  MLB2003129630
# 619                  FULLBASSOSF84KIT       OKDI38047  MLB2003184492
# 625                 FULLBASSOSF105KIT       WJIT31909  MLB2003218577
# 630                FULLBASSOVTFL02KIT       QZJR06663  MLB2003231303
# 634                FULLBASSOVTFL03KIT       TIOX11058  MLB2003244998
# 639                FULLBASSOVTSL53KIT       HGRL10383  MLB2003270402
# 644                FULLBASSOVTFL01KIT       DHEV27121  MLB2003287174
# 648                FULLBASSOVTSL53KIT       BZEY80870  MLB2004757564
# 652                FULLBASSOVTSL82KIT       MSPZ76749  MLB2004757564
# 656                FULLBASSOVTSL87KIT       NJRG06721  MLB2004757564
# 660                FULLBASSOVTSL52KIT       RTIZ80917  MLB2004757564
# 664                FULLBASSOVTSL83KIT       YUZF74492  MLB2004757564
# 669                FULLBASSOVTSL52KIT       ESVG06709  MLB2004830631
# 680         FULLBASSONY07100%JESUSKIT       EATC35944  MLB2006125704
# 684       FULLBASSONY07CRISTOSALVAKIT       TIOX38546  MLB2006294912
# 688                 FULLBASSOVTL01KIT       NZGA07022  MLB2006323551
# 692                 FULLBASSOVTL02KIT       FZQP10396  MLB2006333696
# 697                  FULLBASSODG04KIT       GSZI06869  MLB2006338758
# 705                 FULLBASSOECO02KIT       HFEB10246  MLB2006360215
# 726   FULLLIVERPOOL2NI5AM2NI5BM2NI7AM       HSDO37848  MLB2075516288
# 786                FULLVANDOREN2SR212       EIPZ51427  MLB2770292345
# 791                FULLVANDOREN1SR272       BXUC56742  MLB2774332756
#
#           tiny_sku    tiny_id
# 442        Palheta  565665071
# 446        Palheta  565665071
# 450    AFINADORKIT  597415799
# 466        RH-01GD  746248995
# 474        Palheta  565665071
# 478        Palheta  565665071
# 483        Palheta  565665071
# 488        Palheta  565665071
# 493        Palheta  565665071
# 509        Palheta  565665071
# 513        Palheta  565665071
# 517        Palheta  565665071
# 525        Palheta  565665071
# 543  7897937421021  735947207
# 548        Palheta  565665071
# 554        Palheta  565665071
# 559        Palheta  565665071
# 563        Palheta  565665071
# 569        Palheta  565665071
# 574        Palheta  565665071
# 579        Palheta  565665071
# 583        Palheta  565665071
# 588        Palheta  565665071
# 594        Palheta  565665071
# 598        Palheta  565665071
# 603        Palheta  565665071
# 610        Palheta  565665071
# 614        Palheta  565665071
# 619        Palheta  565665071
# 625        Palheta  565665071
# 630        Palheta  565665071
# 634        Palheta  565665071
# 639        Palheta  565665071
# 644        Palheta  565665071
# 648        Palheta  565665071
# 652        Palheta  565665071
# 656        Palheta  565665071
# 660        Palheta  565665071
# 664        Palheta  565665071
# 669        Palheta  565665071
# 680        Palheta  565665071
# 684        Palheta  565665071
# 688        Palheta  565665071
# 692        Palheta  565665071
# 697        Palheta  565665071
# 705        Palheta  565665071
# 726  7897937421021  735947207
# 786  7897626822115  748837541
# 791  7897626822344  748836965

# %%
lista_coluna1 = dup["ml_inventory_id"].tolist()

# Exibir a lista resultante
print("Lista da coluna 'coluna1':")
print(lista_coluna1)
# Out:
# Lista da coluna 'coluna1':
