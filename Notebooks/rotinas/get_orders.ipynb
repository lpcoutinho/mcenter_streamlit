# %%
import json
import os
import time
from pandas import json_normalize
import psycopg2
from psycopg2 import sql
import math
import pandas as pd
import requests
from dotenv import load_dotenv
from datetime import datetime, timedelta
import numpy as np
from loguru import logger
import datetime

load_dotenv()

ACCESS_TOKEN_MUSICALCRIS = os.getenv("ACCESS_TOKEN_MUSICALCRIS")
SELLER_ID_MUSICALCRIS = os.getenv("SELLER_ID_MUSICALCRIS")

ACCESS_TOKEN_BUENOSHOPS = os.getenv("ACCESS_TOKEN_BUENOSHOPS")
SELLER_ID_BUENOSHOPS = os.getenv("SELLER_ID_BUENOSHOPS")

ACCESS_TOKEN_MCENTER = os.getenv("ACCESS_TOKEN_MCENTER")
SELLER_ID_MCENTER = os.getenv("SELLER_ID_MCENTER")

HOST = os.getenv("HOST")
POSTGRES_DB = os.getenv("POSTGRES_DB")
POSTGRES_USER = os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")

# Informações de conexão com o banco de dados PostgreSQL
db_config = {
    "host": HOST,
    "database": POSTGRES_DB,
    "user": POSTGRES_USER,
    "password": POSTGRES_PASSWORD,
}

# %%
def write_file(json_data, nome_arquivo):
    """
    Escreve dados em um arquivo JSON, adicionando ao arquivo existente se ele já existir.

    Parâmetros:
    - json_data (list): Lista de dados em formato JSON a serem escritos no arquivo.
    - nome_arquivo (str): Nome do arquivo onde os dados serão escritos ou adicionados.

    Exemplo de uso:
    ```python
    json_list = [{'order_id': 1, 'product': 'Item 1'}, {'order_id': 2, 'product': 'Item 2'}]
    write_file(json_list, 'orders.json')
    ```

    Se o arquivo já existir, os dados fornecidos serão adicionados aos dados existentes.
    Se o arquivo não existir, um novo arquivo será criado e os dados serão escritos nele.
    """
    if os.path.exists(nome_arquivo):
        with open(nome_arquivo, "r") as arquivo_existente:
            dados_existente = json.load(arquivo_existente)

        dados_existente.extend(json_data)

        with open(nome_arquivo, "w") as arquivo:
            json.dump(dados_existente, arquivo)
    else:
        with open(nome_arquivo, "w") as arquivo:
            json.dump(json_data, arquivo)

# %%
# Função para obter dados para um intervalo de datas específico
def get_orders_for_date_range(access_token, seller_id, date_from, date_to, table_orders,offset=0, limit=50):
    
    logger.add(
        f"Data/Output/Log/{table_orders}.log",
        rotation="10 MB",
        format="{time:YYYY-MM-DD at HH:mm:ss} | {level} | {message}",
    )
    
    base_url = "https://api.mercadolibre.com/orders/search"

    params = {
        "seller": seller_id,
        "order.date_closed.from": f"{date_from}T00:00:00.000-03:00",
        "order.date_closed.to": f"{date_to}T00:00:00.000-03:00",
        "limit": limit,
        "offset": offset,
    }
    logger.info(params)

    headers = {"Authorization": f"Bearer {access_token}"}
    logger.info(headers)
    
    json_list = []
    counter = 0

    try:
        while True:
            response = requests.get(base_url, params=params, headers=headers)
            response.raise_for_status()
            data = response.json()

            if "results" in data:
                json_list.extend(data["results"])
            else:
                break

            if "paging" in data:
                total_paging = data["paging"].get("total")
                if total_paging is None:
                    break

                total_pages = math.ceil(total_paging / params["limit"])
                logger.info(f"Total esperado de páginas: {counter + 1}/{total_pages}")
                logger.info(f"Total de dados esperados: {total_paging}")
                logger.info(f'Offset atual: {params["offset"]}')
                logger.info(f"Intervalo de datas atual: {date_from} - {date_to}")

                if params["offset"] > total_paging:
                    break

                params["offset"] += params["limit"]
                counter += 1
            else:
                break

    except requests.exceptions.RequestException as req_err:
        logger.info(f"Erro ao fazer a requisição para {base_url}: {req_err}")

    except Exception as e:
        logger.info(f"Erro não esperado: {e}")

    logger.info(f"Total de dados coletados para {date_from} - {date_to}: {len(json_list)}")
    # return json_list
    
    write_file(json_list, f"../../Data/Output/{table_orders}.json")

    resultados = []

    # coletando dados de orders
    for item in json_list:
        # Extrair os valores desejados
        payments = item.get("payments", [])
        status = item["status"]
        date_closed = item["date_closed"]
        pack_id = item["pack_id"]
        shipping = item["shipping"]
        order_items = item.get("order_items", [])
        fulfilled = item["fulfilled"]

        for payment in payments:
            order_id = payment["order_id"]
            reason = payment["reason"]
            payment_status = payment["status"]
            date_approved = payment["date_approved"]

        # Inicializa variável para armazenar shipping_id
        shipping_id = None
        shipping_id = shipping["id"]

        # # Inicializa listas para armazenar informações específicas de order_items

        # Itera sobre os dicionários em order_items
        for order_item in order_items:
            item_info = order_item.get("item", {})
            # item_id = item_info.get("id")
            ml_code = item_info["id"]
            title = item_info["title"]
            variation_id = item_info["variation_id"]
            seller_sku = item_info["seller_sku"]
            quantity = order_item["quantity"]
            category_id = item_info["category_id"]

            variation_attributes = item_info.get("variation_attributes", [])

            name = None
            value_id = None
            value_name = None
            id = None
            for attribute in variation_attributes:
                name = attribute["name"]
                id = attribute["id"]
                value_id = attribute["value_id"]
                value_name = attribute["value_name"]

        # Adicionar os resultados à lista
        resultados.append(
            {
                # "payments": payments,
                "ml_code": ml_code,
                "payment_status": payment_status,
                "order_status": status,
                "order_id": order_id,
                "shipping_id": shipping_id,
                "pack_id": pack_id,
                "title": title,
                "variation_id": variation_id,
                "category_id": category_id,
                "seller_sku": seller_sku,
                "quantity": quantity,
                "variation_name": name,
                "variation_attributes_id": id,
                "variation_value_id": value_id,
                "variation_value_name": value_name,
                "date_approved": date_approved,
                "date_closed": date_closed,
            }
        )

    # Exibir os resultados
    pd.set_option("display.max_colwidth", None)

    df = pd.DataFrame(resultados)

    # Tratando dados numéricos
    pd.set_option("display.float_format", "{:.0f}".format)
    df["shipping_id"] = df["shipping_id"].fillna(0)
    df["pack_id"] = df["pack_id"].fillna(0)
    df["variation_id"] = df["variation_id"].fillna(0)
    df["shipping_id"] = df["shipping_id"].astype("int64")
    df["pack_id"] = df["pack_id"].astype("int64")
    df["variation_id"] = df["variation_id"].astype("int64")


    # Adiciona 1h a mais para chegar ao horário do Brasil
    df["date_approved"] = pd.to_datetime(df["date_approved"])
    df["date_closed"] = pd.to_datetime(df["date_closed"])
    df["date_approved"] = df["date_approved"] + pd.to_timedelta("1 hour")
    df["date_approved"] = df["date_approved"].dt.tz_localize(None)
    df["date_closed"] = df["date_closed"] + pd.to_timedelta("1 hour")
    df["date_closed"] = df["date_closed"].dt.tz_localize(None)
    
    logger.info(df.shape)
    df = df.drop_duplicates()
    logger.info(df.shape)
    
    # coletando logistic type
    json_logistic_list = []
    success_count = 0

    total_iterations = len(df["shipping_id"])
    for index, shipping_id in enumerate(df["shipping_id"], start=1):
        url = f"https://api.mercadolibre.com/shipments/{shipping_id}"

        headers = {"Authorization": f"Bearer {access_token}"}

        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()

            json_data = response.json()
            json_logistic_list.append(json_data)
            success_count += 1
            logger.info(f"Obtido com sucesso para shipping_id {shipping_id}: {json_data}")
        except requests.exceptions.RequestException as e:
            logger.info(f"Erro ao obter dados para shipping_id {shipping_id}: {e}")

        # time.sleep(5)

        # Exibir o progresso
        progress_percentage = (index / total_iterations) * 100
        logger.info(f"Progresso: {index}/{total_iterations} ({progress_percentage:.2f}%)")

    # Exibir os resultados
    logger.info(json_logistic_list)

    # Exibir estatísticas de conclusão
    logger.info(f"Número total de iterações: {total_iterations}")
    logger.info(f"Número de iterações bem-sucedidas: {success_count}")
    logger.info(f"Número de iterações falhadas: {total_iterations - success_count}")
    
    write_file(json_logistic_list, f"../../Data/Output/{table_orders}shipping.json")

    dfx = pd.DataFrame(json_logistic_list)
    # cols = ['id', 'order_id', 'logistic_type']
    cols = ["id", "logistic_type"]
    dfx = dfx[cols]
    # dfx['id'].value_counts()

    logger.info(dfx.shape)
    # dfx.head(3)
    
    # Criar um dicionário a partir de dfx para mapear 'order_id' para 'logistic_type'
    order_id_to_logistic_type = dfx.set_index("id")["logistic_type"].to_dict()

    # Adicionar a coluna 'logistic_type' a df usando o mapeamento
    df_result = df.copy()  # Criar uma cópia de df para manter o original intacto
    df_result["logistic_type"] = df_result["shipping_id"].map(order_id_to_logistic_type)

    logger.info(df_result.shape)
    df_result.head(3)
    
    df_result[["order_id", "shipping_id", "pack_id", "variation_id"]] = df_result[
    ["order_id", "shipping_id", "pack_id", "variation_id"]
    ].astype(str)
    df_result[["order_id", "shipping_id", "pack_id", "variation_id"]]
    
    df_result["variation_attributes_id"] = df_result["variation_attributes_id"].replace(
    "<built-in function id>", None, inplace=True
    )
    
    conn = psycopg2.connect(**db_config)

    cursor = conn.cursor()

    for index, row in df_result.iterrows():
        
        query = f"INSERT INTO {table_orders} (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)"
               
        insert_query = sql.SQL(
            query
        )
        
        logger.info(f"Inserindo dados: {[value for value in row]}")

        print("Inserindo dados:", [value for value in row])
        
        cursor.execute(
            insert_query,
            (
                row["ml_code"],
                row["category_id"],
                row["variation_id"],
                row["seller_sku"],
                row["order_id"],
                row["pack_id"],
                row["quantity"],
                row["title"],
                row["order_status"],
                row["payment_status"],
                row["variation_name"],
                row["variation_attributes_id"],
                row["variation_value_id"],
                row["variation_value_name"],
                row["shipping_id"],
                row["date_approved"],
                row["date_closed"],
                row["logistic_type"],
            ),
        )

    conn.commit()

    # Feche o cursor e a conexão
    cursor.close()
    conn.close()
    logger.info("Dados inseridos com sucesso!")

# %%
today = datetime.date.today()
today = today - datetime.timedelta(days=1)
tomorrow = today + datetime.timedelta(days=2)

today_str = today.strftime("%Y-%m-%d")
tomorrow_str = tomorrow.strftime("%Y-%m-%d")

# %%
get_orders_for_date_range(ACCESS_TOKEN_MUSICALCRIS, SELLER_ID_MUSICALCRIS, today_str, tomorrow_str, 'cris_ot')
# Out:
# 2023-12-12 22:29:40.009 | INFO     | __main__:get_orders_for_date_range:19 - {'seller': '681023789', 'order.date_closed.from': '2023-12-11T00:00:00.000-03:00', 'order.date_closed.to': '2023-12-13T00:00:00.000-03:00', 'limit': 50, 'offset': 0}
# 2023-12-12 22:29:40.014 | INFO     | __main__:get_orders_for_date_range:22 - {'Authorization': 'Bearer APP_USR-2611836769858126-121219-284f39c2931ed3c5cb464d2fdc350ccd-681023789'}
# 2023-12-12 22:29:41.200 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 1/1
# 2023-12-12 22:29:41.204 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 11
# 2023-12-12 22:29:41.207 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 0
# 2023-12-12 22:29:41.212 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:29:42.383 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 2/1
# 2023-12-12 22:29:42.387 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 11
# 2023-12-12 22:29:42.391 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 50
# 2023-12-12 22:29:42.397 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:29:42.402 | INFO     | __main__:get_orders_for_date_range:63 - Total de dados coletados para 2023-12-11 - 2023-12-13: 11
# 2023-12-12 22:29:42.704 | INFO     | __main__:get_orders_for_date_range:163 - (11, 17)
# 2023-12-12 22:29:42.713 | INFO     | __main__:get_orders_for_date_range:165 - (11, 17)
# 2023-12-12 22:29:43.775 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893886362: {'substatus_history': [{'date': '2023-12-11T03:37:23.375-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-11T03:38:08.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T05:12:36.503-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T06:24:11.857-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T06:26:42.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'e7b322bf-45df-42e9-89f7-e1c606028c59', 'pack_hash': '1'}, 'receiver_id': 146736934, 'base_cost': 77.8, 'status_history': {'date_shipped': '2023-12-11T11:51:20.546-04:00', 'date_returned': None, 'date_delivered': '2023-12-11T17:24:58.000-04:00', 'date_first_visit': '2023-12-11T17:24:58.000-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T03:38:08.000-04:00', 'date_ready_to_ship': '2023-12-11T03:38:08.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 243.6, 'priority_class': {'id': '10'}, 'service_id': 277362, 'shipping_items': [{'quantity': 2, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3469737689__1'}, 'description': 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', 'id': 'MLB3469737689', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '10.0x9.0x15.0,720.0'}], 'tracking_number': 'MEL42893886362LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 60.7}, 'id': 42893886362, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-11T17:25:00.005-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T03:37:22.518-04:00', 'date_first_printed': '2023-12-11T06:24:10.867-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 210, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 512746, 'estimated_delivery_final': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 38.9, 'estimated_delivery_limit': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-11T00:00:00.000-03:00', 'pay_before': '2023-12-11T11:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 0, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario a domicilio', 'id': 3886906475, 'estimated_delivery_extended': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP04', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Paineira (Jordanésia)'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'B ...
# 2023-12-12 22:29:43.780 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 1/11 (9.09%)
# 2023-12-12 22:29:45.065 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893883121: {'substatus_history': [{'date': '2023-12-11T06:33:44.424-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-11T06:34:23.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T07:51:11.383-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T09:05:38.932-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T09:27:11.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': '1da5c4d5-c52b-406d-aab1-f853de6b7fd8', 'pack_hash': '2'}, 'receiver_id': 200133107, 'base_cost': 38.9, 'status_history': {'date_shipped': '2023-12-11T11:52:18.682-04:00', 'date_returned': None, 'date_delivered': '2023-12-11T18:36:20.000-04:00', 'date_first_visit': '2023-12-11T18:36:20.000-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T06:34:23.000-04:00', 'date_ready_to_ship': '2023-12-11T06:34:23.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 354.28, 'priority_class': {'id': '10'}, 'service_id': 277362, 'shipping_items': [{'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3469737689__1'}, 'description': 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', 'id': 'MLB3469737689', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '10.0x15.0x20.0,580.0'}], 'tracking_number': 'MEL42893883121LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 60.2}, 'id': 42893883121, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-11T18:36:22.387-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T06:33:43.511-04:00', 'date_first_printed': '2023-12-11T09:05:37.588-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 210, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 512746, 'estimated_delivery_final': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 19.45, 'estimated_delivery_limit': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-11T00:00:00.000-03:00', 'pay_before': '2023-12-11T11:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 0, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario a domicilio', 'id': 998711255, 'estimated_delivery_extended': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP04', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Paineira (Jordanésia)'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name':  ...
# 2023-12-12 22:29:45.070 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 2/11 (18.18%)
# 2023-12-12 22:29:46.142 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42894357379: {'substatus_history': [{'date': '2023-12-11T09:29:43.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-12T16:52:08.719-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-12T18:15:34.840-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-12T19:56:54.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'a02e339e-7bc0-4593-8ee0-048cc81377c3', 'pack_hash': '1'}, 'receiver_id': 176826948, 'base_cost': 60.5, 'status_history': {'date_shipped': None, 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T09:29:43.000-04:00', 'date_ready_to_ship': '2023-12-11T09:29:43.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 838, 'priority_class': {'id': '10'}, 'service_id': 508360, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3472441621__1'}, 'description': 'Guitarra Elétrica Tagima Tw Series Tg-530 Stratocaster De  Tília Sunburst Com Diapasão De Bordo', 'id': 'MLB3472441621', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '8.0x107.0x42.0,4250.0'}], 'tracking_number': 'MEL42894357379LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 19.55, 'ratio': 81.9}, 'id': 42894357379, 'tracking_method': 'MEL Voluminoso', 'last_updated': '2023-12-12T19:56:54.600-04:00', 'items_types': ['new'], 'comments': None, 'substatus': 'in_packing_list', 'date_created': '2023-12-11T09:26:29.884-04:00', 'date_first_printed': '2023-12-12T18:15:33.550-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 720, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 100009, 'estimated_delivery_final': {'date': '2023-12-14T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': '2023-12-12T00:00:00.000Z'}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 40.95, 'estimated_delivery_limit': {'date': '2023-12-14T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-14T00:00:00.000-03:00', 'pay_before': '2023-12-13T04:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': '2023-12-15T00:00:00.000-03:00', 'shipping': 24}, 'shipping': 48, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known_frame'}, 'name': 'Normal', 'id': 982600031, 'estimated_delivery_extended': {'date': '2023-12-14T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP10', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlJGcmFuY28gZGEgUm9jaGE', 'name': 'Franco da Rocha'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Parque Santa Delfa'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Quadra 8 SN', 'types': ['default_ ...
# 2023-12-12 22:29:46.146 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 3/11 (27.27%)
# 2023-12-12 22:29:47.206 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42894896728: {'substatus_history': [{'date': '2023-12-11T11:01:44.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T12:04:27.572-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T13:34:09.490-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T14:52:40.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': '8bcfccb3-33a9-4a9e-a5f4-e55bf8ff9c5a', 'pack_hash': '1'}, 'receiver_id': 347805085, 'base_cost': 57.3, 'status_history': {'date_shipped': '2023-12-11T17:45:38.000-04:00', 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T11:01:44.000-04:00', 'date_ready_to_ship': '2023-12-11T11:01:44.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 2118, 'priority_class': {'id': '10'}, 'service_id': 508360, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3468483295__1'}, 'description': 'Guitarra Elétrica Ibanez Rg Gio Grx70qa De  Choupo Transparent Red Burst Com Diapasão De Amaranto', 'id': 'MLB3468483295', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '9.0x106.0x45.0,4500.0'}], 'tracking_number': 'MEL42894896728LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 98.25}, 'id': 42894896728, 'tracking_method': 'MEL Voluminoso', 'last_updated': '2023-12-12T18:01:05.275-04:00', 'items_types': ['new'], 'comments': None, 'substatus': 'out_for_delivery', 'date_created': '2023-12-11T11:01:39.016-04:00', 'date_first_printed': '2023-12-11T13:34:08.556-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 240, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 507946, 'estimated_delivery_final': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 40.95, 'estimated_delivery_limit': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-13T00:00:00.000-03:00', 'pay_before': '2023-12-11T23:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 48, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario', 'id': 4184331391, 'estimated_delivery_extended': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP02', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Colina'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua Júlio Espanhol Vicente 7', 'types': ['billing', 'defa ...
# 2023-12-12 22:29:47.211 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 4/11 (36.36%)
# 2023-12-12 22:29:48.215 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42894861733: {'substatus_history': [{'date': '2023-12-11T11:21:26.688-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-11T11:22:16.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-12T09:03:08.252-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-12T10:41:53.768-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-12T10:49:48.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'ba02ac92-eb9d-4604-bf96-865e0fd6d295', 'pack_hash': '1'}, 'receiver_id': 351691151, 'base_cost': 38.9, 'status_history': {'date_shipped': None, 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T11:22:16.000-04:00', 'date_ready_to_ship': '2023-12-11T11:22:16.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 150.79, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3469737689__1'}, 'description': 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', 'id': 'MLB3469737689', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '7.0x18.0x18.0,410.0'}], 'tracking_number': 'MEL42894861733LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': -4.75, 'ratio': 38.9}, 'id': 42894861733, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T10:49:49.258-04:00', 'items_types': ['new'], 'comments': None, 'substatus': 'in_packing_list', 'date_created': '2023-12-11T11:21:25.023-04:00', 'date_first_printed': '2023-12-12T10:41:51.849-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 210, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 182, 'estimated_delivery_final': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': '2023-12-12T00:00:00.000Z'}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 19.45, 'estimated_delivery_limit': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-12T00:00:00.000-03:00', 'pay_before': '2023-12-11T23:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': '2023-12-13T00:00:00.000-03:00', 'shipping': 24}, 'shipping': 24, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known_frame'}, 'name': 'Expresso', 'id': 4214773677, 'estimated_delivery_extended': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP02', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Colina'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua D ...
# 2023-12-12 22:29:48.218 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 5/11 (45.45%)
# 2023-12-12 22:29:49.370 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42895306822: {'substatus_history': [{'date': '2023-12-11T12:30:03.027-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-11T12:30:47.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T19:30:03.552-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T20:14:55.483-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-12T01:43:04.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'bddf69ba-4e4f-4b5e-b9d8-812286ec04aa', 'pack_hash': '1'}, 'receiver_id': 1353690595, 'base_cost': 77.8, 'status_history': {'date_shipped': '2023-12-12T07:48:54.402-04:00', 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T12:30:47.000-04:00', 'date_ready_to_ship': '2023-12-11T12:30:47.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 243.6, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'quantity': 2, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3469737689__1'}, 'description': 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', 'id': 'MLB3469737689', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '10.0x9.0x15.0,720.0'}], 'tracking_number': 'MEL42895306822LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 77.1}, 'id': 42895306822, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T07:48:57.828-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T12:30:02.236-04:00', 'date_first_printed': '2023-12-11T20:14:54.517-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 210, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 507946, 'estimated_delivery_final': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 38.9, 'estimated_delivery_limit': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-13T00:00:00.000-03:00', 'pay_before': '2023-12-12T05:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 120, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario', 'id': 4109282320, 'estimated_delivery_extended': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP02', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Colina'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua da Feição 46', 'types': ['default_buyi ...
# 2023-12-12 22:29:49.374 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 6/11 (54.55%)
# 2023-12-12 22:29:50.395 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42897054396: {'substatus_history': [{'date': '2023-12-11T19:04:23.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T20:19:40.562-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T20:56:38.083-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T21:25:48.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}, {'date': '2023-12-12T11:14:26.742-04:00', 'substatus': 'waiting_for_withdrawal', 'status': 'shipped'}], 'snapshot_packing': {'snapshot_id': '05962b5e-1841-45e8-be6f-b9051ad46ce2', 'pack_hash': '1'}, 'receiver_id': 126237619, 'base_cost': 24.8, 'status_history': {'date_shipped': '2023-12-12T00:19:40.000-04:00', 'date_returned': None, 'date_delivered': '2023-12-12T16:33:56.914-04:00', 'date_first_visit': '2023-12-12T11:14:26.742-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T19:04:23.000-04:00', 'date_ready_to_ship': '2023-12-11T19:04:23.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 2013, 'priority_class': {'id': '10'}, 'service_id': 255682, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB4097062232__1'}, 'description': 'Guitarra Elétrica Ibanez Rg Gio Grg121dx Soloist De  Okoume Walnut Flat Com Diapasão De Amaranto', 'id': 'MLB4097062232', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '9.0x106.0x45.0,3750.0'}], 'tracking_number': 'MEL42897054396LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 65.75}, 'id': 42897054396, 'tracking_method': 'Agências Mercado Livre', 'last_updated': '2023-12-12T16:33:57.955-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T19:03:07.258-04:00', 'date_first_printed': '2023-12-11T20:56:36.907-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 720, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 512146, 'estimated_delivery_final': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 40.95, 'estimated_delivery_limit': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-12T00:00:00.000-03:00', 'pay_before': '2023-12-11T22:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 24, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Retiro Prioritario na agência', 'id': 3104373590, 'estimated_delivery_extended': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP10', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlJGcmFuY28gZGEgUm9jaGE', 'name': 'Franco da Rocha'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Parque Santa Delfa'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_in ...
# 2023-12-12 22:29:50.398 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 7/11 (63.64%)
# 2023-12-12 22:29:51.493 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42897478218: {'substatus_history': [{'date': '2023-12-11T20:41:00.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T21:10:01.589-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T22:33:30.209-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T22:46:50.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'd35f94fc-4ae6-4e37-9fe1-7a8f5f7dc2cd', 'pack_hash': '1'}, 'receiver_id': 207527981, 'base_cost': 18.6, 'status_history': {'date_shipped': '2023-12-12T00:37:36.476-04:00', 'date_returned': None, 'date_delivered': '2023-12-12T14:48:08.000-04:00', 'date_first_visit': '2023-12-12T14:48:08.000-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T20:41:00.000-04:00', 'date_ready_to_ship': '2023-12-11T20:41:00.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 324.73, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB2077624899-173883881289'}, 'description': 'Mini Acordeon Instrumento Musical Crianças Verde/vermelho', 'id': 'MLB2077624899', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '13.0x25.0x26.0,1480.0'}], 'tracking_number': 'MEL42897478218LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 41.05}, 'id': 42897478218, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T14:48:09.175-04:00', 'items_types': ['new', 'fragile'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T20:36:09.793-04:00', 'date_first_printed': '2023-12-11T22:33:28.437-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 150, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 507945, 'estimated_delivery_final': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 22.45, 'estimated_delivery_limit': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-12T00:00:00.000-03:00', 'pay_before': '2023-12-11T23:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 24, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario', 'id': 4085712087, 'estimated_delivery_extended': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP02', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Colina'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Avenida Paula Ferreira 2097', 't ...
# 2023-12-12 22:29:51.497 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 8/11 (72.73%)
# 2023-12-12 22:29:52.510 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42899217166: {'substatus_history': [{'date': '2023-12-12T09:46:22.710-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-12T09:47:11.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'dd7ad2af-8fc3-4617-84d8-9e96cd40c523', 'pack_hash': '1'}, 'receiver_id': 367904333, 'base_cost': 42.9, 'status_history': {'date_shipped': None, 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-12T09:47:11.000-04:00', 'date_ready_to_ship': '2023-12-12T09:47:11.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 209, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3472524897-180196117171'}, 'description': 'Ukulele Acústico Soprano 21-k Tagima Nylon - Natural Satin', 'id': 'MLB3472524897', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '9.0x23.0x55.0,620.0'}], 'tracking_number': 'MEL42899217166LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 4.05, 'ratio': 42.9}, 'id': 42899217166, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T09:47:24.295-04:00', 'items_types': ['fragile', 'new'], 'comments': None, 'substatus': 'in_warehouse', 'date_created': '2023-12-12T09:46:20.346-04:00', 'date_first_printed': None, 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 720, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 100009, 'estimated_delivery_final': {'date': '2023-12-15T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': '2023-12-13T00:00:00.000Z'}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 21.45, 'estimated_delivery_limit': {'date': '2023-12-15T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-15T00:00:00.000-03:00', 'pay_before': '2023-12-14T07:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': '2023-12-16T00:00:00.000-03:00', 'shipping': 24}, 'shipping': 24, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known_frame'}, 'name': 'Normal', 'id': 3383400108, 'estimated_delivery_extended': {'date': '2023-12-15T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP10', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlJGcmFuY28gZGEgUm9jaGE', 'name': 'Franco da Rocha'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Parque Santa Delfa'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua Alemanha 100', 'types': [], 'scoring': 4.82, 'agency': None, 'city': {'id': 'TUxCQ0pPSTc2NzM4', 'name': 'Joinville'}, 'geolocation_type': 'ROOFTOP', 'latitude': -26.303209, 'municipality': {'id': None, 'name': None}, 'location_id': 391900, 'street_name': 'Rua Alemanha', 'zip_code': '89216226',  ...
# 2023-12-12 22:29:52.513 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 9/11 (81.82%)
# 2023-12-12 22:29:53.595 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42900018309: {'substatus_history': [{'date': '2023-12-12T13:08:12.929-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-12T13:08:56.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-12T14:15:56.520-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-12T15:54:00.598-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-12T16:08:43.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'a7f47ee9-be22-488d-92d9-ea6fcc5a9ad7', 'pack_hash': '1'}, 'receiver_id': 122871809, 'base_cost': 44.9, 'status_history': {'date_shipped': None, 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-12T13:08:56.000-04:00', 'date_ready_to_ship': '2023-12-12T13:08:56.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 490.65, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB2077566813__1'}, 'description': 'Mini Acordeon Infantil Sanfona Para Crianças Turbinho Azul', 'id': 'MLB2077566813', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '26.0x17.0x34.0,2390.0'}], 'tracking_number': 'MEL42900018309LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 62.1}, 'id': 42900018309, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T16:08:44.480-04:00', 'items_types': ['new'], 'comments': None, 'substatus': 'in_packing_list', 'date_created': '2023-12-12T13:08:12.089-04:00', 'date_first_printed': '2023-12-12T15:53:58.389-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 210, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 507945, 'estimated_delivery_final': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 22.45, 'estimated_delivery_limit': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-13T00:00:00.000-03:00', 'pay_before': '2023-12-12T20:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 24, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario', 'id': 1819440888, 'estimated_delivery_extended': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP02', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Colina'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Avenida Alfredo Ravaneli 7985', 'types': ['def ...
# 2023-12-12 22:29:53.599 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 10/11 (90.91%)
# 2023-12-12 22:29:54.587 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42900601412: {'substatus_history': [{'date': '2023-12-12T14:47:41.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': '3427101c-bd37-4bd3-959b-4a00928c9e04', 'pack_hash': '1'}, 'receiver_id': 617138146, 'base_cost': 57.2, 'status_history': {'date_shipped': None, 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-12T14:47:41.000-04:00', 'date_ready_to_ship': '2023-12-12T14:47:41.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 1536, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3469722247__1'}, 'description': 'Mesa De Som Profissional 16 Canais Bluetooth Cpp-16 Waldman Bivolt', 'id': 'MLB3469722247', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '40.0x49.0x15.0,4540.0'}], 'tracking_number': 'MEL42900601412LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 81.15}, 'id': 42900601412, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T14:48:54.380-04:00', 'items_types': ['new'], 'comments': None, 'substatus': 'in_warehouse', 'date_created': '2023-12-12T14:47:34.956-04:00', 'date_first_printed': None, 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 720, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 100009, 'estimated_delivery_final': {'date': '2023-12-19T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': '2023-12-13T00:00:00.000Z'}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 23.95, 'estimated_delivery_limit': {'date': '2023-12-19T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-19T00:00:00.000-03:00', 'pay_before': '2023-12-13T23:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 144, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Normal', 'id': 3436563249, 'estimated_delivery_extended': {'date': '2023-12-19T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP10', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlJGcmFuY28gZGEgUm9jaGE', 'name': 'Franco da Rocha'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Parque Santa Delfa'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Praça Santa Teresinha SN', 'types': ['billing', 'default_buying_address', 'default_return_address', 'default_selling_address', 'shipping'], 'scoring': 2.89, 'agency': None, 'city': {'id': 'TUxCQ0JBQ2UwNGQ2', 'name': 'Bacabal'}, 'geolocation_type': 'ROOFTOP', 'latitude': -4.227587, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'Praça Santa Teresinha', 'zip_code': '65700000', 'geol ...
# 2023-12-12 22:29:54.591 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 11/11 (100.00%)
# 2023-12-12 22:29:54.595 | INFO     | __main__:get_orders_for_date_range:195 - [{'substatus_history': [{'date': '2023-12-11T03:37:23.375-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-11T03:38:08.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T05:12:36.503-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T06:24:11.857-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T06:26:42.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'e7b322bf-45df-42e9-89f7-e1c606028c59', 'pack_hash': '1'}, 'receiver_id': 146736934, 'base_cost': 77.8, 'status_history': {'date_shipped': '2023-12-11T11:51:20.546-04:00', 'date_returned': None, 'date_delivered': '2023-12-11T17:24:58.000-04:00', 'date_first_visit': '2023-12-11T17:24:58.000-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T03:38:08.000-04:00', 'date_ready_to_ship': '2023-12-11T03:38:08.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 681023789, 'mode': 'me2', 'order_cost': 243.6, 'priority_class': {'id': '10'}, 'service_id': 277362, 'shipping_items': [{'quantity': 2, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3469737689__1'}, 'description': 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', 'id': 'MLB3469737689', 'user_product_id': None, 'sender_id': 681023789, 'dimensions': '10.0x9.0x15.0,720.0'}], 'tracking_number': 'MEL42893886362LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 60.7}, 'id': 42893886362, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-11T17:25:00.005-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T03:37:22.518-04:00', 'date_first_printed': '2023-12-11T06:24:10.867-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 210, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 512746, 'estimated_delivery_final': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 38.9, 'estimated_delivery_limit': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-11T00:00:00.000-03:00', 'pay_before': '2023-12-11T11:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 0, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario a domicilio', 'id': 3886906475, 'estimated_delivery_extended': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP04', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Paineira (Jordanésia)'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Avenida Doutor Moura R ...
# 2023-12-12 22:29:54.602 | INFO     | __main__:get_orders_for_date_range:198 - Número total de iterações: 11
# 2023-12-12 22:29:54.606 | INFO     | __main__:get_orders_for_date_range:199 - Número de iterações bem-sucedidas: 11
# 2023-12-12 22:29:54.610 | INFO     | __main__:get_orders_for_date_range:200 - Número de iterações falhadas: 0
# 2023-12-12 22:29:54.738 | INFO     | __main__:get_orders_for_date_range:210 - (11, 2)
# 2023-12-12 22:29:54.745 | INFO     | __main__:get_orders_for_date_range:220 - (11, 18)
# 2023-12-12 22:29:55.352 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# 2023-12-12 22:29:55.357 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB3469737689', 'approved', 'paid', '2000007114829158', '42893886362', '2000005156308807', 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', '0', 'MLB135939', 'C4DI1PSFULL', 2, None, None, None, None, Timestamp('2023-12-11 04:38:05'), Timestamp('2023-12-11 04:38:05'), 'fulfillment']
# 2023-12-12 22:29:55.395 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# 2023-12-12 22:29:55.398 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB3469737689', 'approved', 'paid', '2000007115094810', '42893883121', '2000005156443029', 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', '0', 'MLB135939', 'C4DI1PSFULL', 1, None, None, None, None, Timestamp('2023-12-11 07:34:18'), Timestamp('2023-12-11 07:34:19'), 'fulfillment']
# 2023-12-12 22:29:55.417 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# 2023-12-12 22:29:55.422 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB3472441621', 'approved', 'paid', '2000007116148588', '42894357379', '0', 'Guitarra Elétrica Tagima Tw Series Tg-530 Stratocaster De  Tília Sunburst Com Diapasão De Bordo', '0', 'MLB438516', 'C4TG530SBFULL', 1, None, None, None, None, Timestamp('2023-12-11 10:29:39'), Timestamp('2023-12-11 10:29:39'), 'fulfillment']
# 2023-12-12 22:29:55.443 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# 2023-12-12 22:29:55.447 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB3468483295', 'approved', 'paid', '2000007117098618', '42894896728', '0', 'Guitarra Elétrica Ibanez Rg Gio Grx70qa De  Choupo Transparent Red Burst Com Diapasão De Amaranto', '0', 'MLB438516', 'C4GRX70QATRBFULL', 1, None, None, None, None, Timestamp('2023-12-11 12:01:41'), Timestamp('2023-12-11 12:01:41'), 'fulfillment']
# 2023-12-12 22:29:55.468 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# 2023-12-12 22:29:55.474 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB3469737689', 'approved', 'paid', '2000007117295974', '42894861733', '2000005157473049', 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', '0', 'MLB135939', 'C4DI1PSFULL', 1, None, None, None, None, Timestamp('2023-12-11 12:22:13'), Timestamp('2023-12-11 12:22:14'), 'fulfillment']
# 2023-12-12 22:29:55.514 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# 2023-12-12 22:29:55.518 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB3469737689', 'approved', 'paid', '2000007118052396', '42895306822', '2000005157855405', 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', '0', 'MLB135939', 'C4DI1PSFULL', 2, None, None, None, None, Timestamp('2023-12-11 13:30:42'), Timestamp('2023-12-11 13:30:42'), 'fulfillment']
# 2023-12-12 22:29:55.537 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# Inserindo dados: ['MLB3469737689', 'approved', 'paid', '2000007114829158', '42893886362', '2000005156308807', 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', '0', 'MLB135939', 'C4DI1PSFULL', 2, None, None, None, None, Timestamp('2023-12-11 04:38:05'), Timestamp('2023-12-11 04:38:05'), 'fulfillment']
# Inserindo dados: ['MLB3469737689', 'approved', 'paid', '2000007115094810', '42893883121', '2000005156443029', 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', '0', 'MLB135939', 'C4DI1PSFULL', 1, None, None, None, None, Timestamp('2023-12-11 07:34:18'), Timestamp('2023-12-11 07:34:19'), 'fulfillment']
# Inserindo dados: ['MLB3472441621', 'approved', 'paid', '2000007116148588', '42894357379', '0', 'Guitarra Elétrica Tagima Tw Series Tg-530 Stratocaster De  Tília Sunburst Com Diapasão De Bordo', '0', 'MLB438516', 'C4TG530SBFULL', 1, None, None, None, None, Timestamp('2023-12-11 10:29:39'), Timestamp('2023-12-11 10:29:39'), 'fulfillment']
# Inserindo dados: ['MLB3468483295', 'approved', 'paid', '2000007117098618', '42894896728', '0', 'Guitarra Elétrica Ibanez Rg Gio Grx70qa De  Choupo Transparent Red Burst Com Diapasão De Amaranto', '0', 'MLB438516', 'C4GRX70QATRBFULL', 1, None, None, None, None, Timestamp('2023-12-11 12:01:41'), Timestamp('2023-12-11 12:01:41'), 'fulfillment']
# Inserindo dados: ['MLB3469737689', 'approved', 'paid', '2000007117295974', '42894861733', '2000005157473049', 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', '0', 'MLB135939', 'C4DI1PSFULL', 1, None, None, None, None, Timestamp('2023-12-11 12:22:13'), Timestamp('2023-12-11 12:22:14'), 'fulfillment']
# Inserindo dados: ['MLB3469737689', 'approved', 'paid', '2000007118052396', '42895306822', '2000005157855405', 'Direct Box Passivo Waldman Bypass Di-1ps - 1 Canal', '0', 'MLB135939', 'C4DI1PSFULL', 2, None, None, None, None, Timestamp('2023-12-11 13:30:42'), Timestamp('2023-12-11 13:30:42'), 'fulfillment']
# 2023-12-12 22:29:55.543 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB4097062232', 'approved', 'paid', '2000007122121374', '42897054396', '0', 'Guitarra Elétrica Ibanez Rg Gio Grg121dx Soloist De  Okoume Walnut Flat Com Diapasão De Amaranto', '0', 'MLB438516', 'C4GRG121DXWNFFULL', 1, None, None, None, None, Timestamp('2023-12-11 20:04:20'), Timestamp('2023-12-11 20:04:20'), 'fulfillment']
# 2023-12-12 22:29:55.571 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# 2023-12-12 22:29:55.575 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB2077624899', 'approved', 'paid', '2000007123114922', '42897478218', '0', 'Mini Acordeon Instrumento Musical Crianças Verde/vermelho', '173883881289', 'MLB72749', '7898475673552', 1, 'Cor', None, None, 'Vermelho-Verde', Timestamp('2023-12-11 21:39:56'), Timestamp('2023-12-11 21:40:58'), 'fulfillment']
# 2023-12-12 22:29:55.592 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# 2023-12-12 22:29:55.596 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB3472524897', 'approved', 'paid', '2000007127239130', '42899217166', '2000005162652363', 'Ukulele Acústico Soprano 21-k Tagima Nylon - Natural Satin', '180196117171', 'MLB202371', 'C421KNSFULL', 1, 'Cor', None, '52005', 'Marrom', Timestamp('2023-12-12 10:47:06'), Timestamp('2023-12-12 10:47:06'), 'fulfillment']
# 2023-12-12 22:29:55.613 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# 2023-12-12 22:29:55.618 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB2077566813', 'approved', 'paid', '2000007129357620', '42900018309', '2000005163706231', 'Mini Acordeon Infantil Sanfona Para Crianças Turbinho Azul', '0', 'MLB270110', 'C4AT104BLFULL', 1, None, None, None, None, Timestamp('2023-12-12 14:08:53'), Timestamp('2023-12-12 14:08:53'), 'fulfillment']
# 2023-12-12 22:29:55.639 | INFO     | __main__:get_orders_for_date_range:243 - SQL('INSERT INTO cris_ot (ml_code,category_id,variation_id,seller_sku,order_id,pack_id,quantity,title,order_status,payment_status,variation_name,variation_attributes_id,variation_value_id,variation_value_name,shipping_id,date_approved,date_closed,logistic_type) VALUES (%s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s, %s, %s, %s, %s, %s)')
# 2023-12-12 22:29:55.643 | INFO     | __main__:get_orders_for_date_range:247 - Inserindo dados: ['MLB3469722247', 'approved', 'paid', '2000007130434830', '42900601412', '0', 'Mesa De Som Profissional 16 Canais Bluetooth Cpp-16 Waldman Bivolt', '0', 'MLB29281', 'C4CPP16FXUFULL', 1, None, None, None, None, Timestamp('2023-12-12 15:47:38'), Timestamp('2023-12-12 15:47:38'), 'fulfillment']
# 2023-12-12 22:29:55.678 | INFO     | __main__:get_orders_for_date_range:281 - Dados inseridos com sucesso!
# Inserindo dados: ['MLB4097062232', 'approved', 'paid', '2000007122121374', '42897054396', '0', 'Guitarra Elétrica Ibanez Rg Gio Grg121dx Soloist De  Okoume Walnut Flat Com Diapasão De Amaranto', '0', 'MLB438516', 'C4GRG121DXWNFFULL', 1, None, None, None, None, Timestamp('2023-12-11 20:04:20'), Timestamp('2023-12-11 20:04:20'), 'fulfillment']
# Inserindo dados: ['MLB2077624899', 'approved', 'paid', '2000007123114922', '42897478218', '0', 'Mini Acordeon Instrumento Musical Crianças Verde/vermelho', '173883881289', 'MLB72749', '7898475673552', 1, 'Cor', None, None, 'Vermelho-Verde', Timestamp('2023-12-11 21:39:56'), Timestamp('2023-12-11 21:40:58'), 'fulfillment']
# Inserindo dados: ['MLB3472524897', 'approved', 'paid', '2000007127239130', '42899217166', '2000005162652363', 'Ukulele Acústico Soprano 21-k Tagima Nylon - Natural Satin', '180196117171', 'MLB202371', 'C421KNSFULL', 1, 'Cor', None, '52005', 'Marrom', Timestamp('2023-12-12 10:47:06'), Timestamp('2023-12-12 10:47:06'), 'fulfillment']
# Inserindo dados: ['MLB2077566813', 'approved', 'paid', '2000007129357620', '42900018309', '2000005163706231', 'Mini Acordeon Infantil Sanfona Para Crianças Turbinho Azul', '0', 'MLB270110', 'C4AT104BLFULL', 1, None, None, None, None, Timestamp('2023-12-12 14:08:53'), Timestamp('2023-12-12 14:08:53'), 'fulfillment']
# Inserindo dados: ['MLB3469722247', 'approved', 'paid', '2000007130434830', '42900601412', '0', 'Mesa De Som Profissional 16 Canais Bluetooth Cpp-16 Waldman Bivolt', '0', 'MLB29281', 'C4CPP16FXUFULL', 1, None, None, None, None, Timestamp('2023-12-12 15:47:38'), Timestamp('2023-12-12 15:47:38'), 'fulfillment']

# %%
# get_orders_for_date_range(ACCESS_TOKEN_BUENOSHOPS, SELLER_ID_BUENOSHOPS, today_str, tomorrow_str, 'cris_ot')

# %%
get_orders_for_date_range(ACCESS_TOKEN_MCENTER, SELLER_ID_MCENTER, today_str, tomorrow_str, 'mcenter_ot')
# Out:
# 2023-12-12 22:21:30.636 | INFO     | __main__:get_orders_for_date_range:19 - {'seller': '233632476', 'order.date_closed.from': '2023-12-11T00:00:00.000-03:00', 'order.date_closed.to': '2023-12-13T00:00:00.000-03:00', 'limit': 50, 'offset': 0}
# 2023-12-12 22:21:30.641 | INFO     | __main__:get_orders_for_date_range:22 - {'Authorization': 'Bearer APP_USR-6628000663056293-121221-92736a8ce258ab9545146295da6db549-233632476'}
# 2023-12-12 22:21:32.100 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 1/11
# 2023-12-12 22:21:32.104 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:32.107 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 0
# 2023-12-12 22:21:32.110 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:33.454 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 2/11
# 2023-12-12 22:21:33.456 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:33.459 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 50
# 2023-12-12 22:21:33.462 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:34.843 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 3/11
# 2023-12-12 22:21:34.846 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:34.850 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 100
# 2023-12-12 22:21:34.853 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:36.137 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 4/11
# 2023-12-12 22:21:36.140 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:36.143 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 150
# 2023-12-12 22:21:36.146 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:37.896 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 5/11
# 2023-12-12 22:21:37.898 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:37.901 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 200
# 2023-12-12 22:21:37.903 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:39.273 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 6/11
# 2023-12-12 22:21:39.275 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:39.279 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 250
# 2023-12-12 22:21:39.281 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:40.718 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 7/11
# 2023-12-12 22:21:40.720 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:40.723 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 300
# 2023-12-12 22:21:40.727 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:42.114 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 8/11
# 2023-12-12 22:21:42.117 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:42.119 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 350
# 2023-12-12 22:21:42.122 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:43.414 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 9/11
# 2023-12-12 22:21:43.416 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:43.419 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 400
# 2023-12-12 22:21:43.421 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:44.520 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 10/11
# 2023-12-12 22:21:44.522 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:44.525 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 450
# 2023-12-12 22:21:44.528 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:45.748 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 11/11
# 2023-12-12 22:21:45.751 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:45.754 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 500
# 2023-12-12 22:21:45.756 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:46.814 | INFO     | __main__:get_orders_for_date_range:44 - Total esperado de páginas: 12/11
# 2023-12-12 22:21:46.816 | INFO     | __main__:get_orders_for_date_range:45 - Total de dados esperados: 508
# 2023-12-12 22:21:46.819 | INFO     | __main__:get_orders_for_date_range:46 - Offset atual: 550
# 2023-12-12 22:21:46.822 | INFO     | __main__:get_orders_for_date_range:47 - Intervalo de datas atual: 2023-12-11 - 2023-12-13
# 2023-12-12 22:21:46.825 | INFO     | __main__:get_orders_for_date_range:63 - Total de dados coletados para 2023-12-11 - 2023-12-13: 508
# 2023-12-12 22:21:47.231 | INFO     | __main__:get_orders_for_date_range:163 - (508, 17)
# 2023-12-12 22:21:47.239 | INFO     | __main__:get_orders_for_date_range:165 - (508, 17)
# 2023-12-12 22:21:48.331 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893582426: {'substatus_history': [{'date': '2023-12-10T23:17:51.000-04:00', 'substatus': 'invoice_pending', 'status': 'ready_to_ship'}, {'date': '2023-12-11T10:37:29.051-04:00', 'substatus': 'waiting_for_carrier_authorization', 'status': 'ready_to_ship'}, {'date': '2023-12-11T10:37:30.281-04:00', 'substatus': 'ready_to_print', 'status': 'ready_to_ship'}, {'date': '2023-12-11T16:18:28.000-04:00', 'substatus': 'picked_up', 'status': 'ready_to_ship'}, {'date': '2023-12-11T19:00:33.000-04:00', 'substatus': 'in_hub', 'status': 'ready_to_ship'}, {'date': '2023-12-11T19:00:34.629-04:00', 'substatus': 'authorized_by_carrier', 'status': 'ready_to_ship'}, {'date': '2023-12-12T00:49:01.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'd0f49f5b-e07b-4929-8b61-4a24d03cff8b', 'pack_hash': '1'}, 'receiver_id': 24953140, 'base_cost': 37.3, 'status_history': {'date_shipped': '2023-12-12T08:39:31.850-04:00', 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-10T23:17:51.000-04:00', 'date_ready_to_ship': '2023-12-10T23:17:51.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 222.9, 'priority_class': {'id': '20'}, 'service_id': 157861, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'product_conciliation', 'id': 'MLB3493414145__1'}, 'description': 'Correia Violão Guitarra Orleans Jacquard P04150 Ernie Ball', 'id': 'MLB3493414145', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '7.0x27.0x40.0,350.0'}], 'tracking_number': 'MEL42893582426LMXDF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 17.85, 'ratio': 38.9}, 'id': 42893582426, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T08:39:35.798-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-10T23:17:42.782-04:00', 'date_first_printed': '2023-12-11T12:43:27.754-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': None, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 182, 'estimated_delivery_final': {'date': '2023-12-15T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 19.45, 'estimated_delivery_limit': {'date': '2023-12-15T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '20'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': '2023-12-11T00:00:00.000-03:00'}, 'estimated_delivery_time': {'date': '2023-12-15T00:00:00.000-03:00', 'pay_before': None, 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 72, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Expresso', 'id': 641302667, 'estimated_delivery_extended': {'date': '2023-12-15T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['default_return_address', 'shipping'], 'scoring': 3.34, 'agency': None, 'city': {'id': 'BR-SP-44', 'name': 'São Paulo'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': 516323, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': 'geolocation-feedback', 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': 1316706177, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Conjunto Habitacional Santa Etelvina II'}, 'geolocation_last_updated': '2023-08-18T15:58:47.395Z', 'longitude': 0}, 'sibling': {'reason': ...
# 2023-12-12 22:21:48.335 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 1/508 (0.20%)
# 2023-12-12 22:21:49.514 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893481001: {'substatus_history': [{'date': '2023-12-10T23:26:45.125-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}], 'snapshot_packing': {'snapshot_id': 'ad2738a3-67b3-4924-bae4-501c373f700f', 'pack_hash': '7'}, 'receiver_id': 29064932, 'base_cost': 13.52, 'status_history': {'date_shipped': '2023-12-11T16:31:21.214-04:00', 'date_returned': None, 'date_delivered': '2023-12-11T17:59:25.269-04:00', 'date_first_visit': '2023-12-11T17:59:25.269-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-10T23:26:48.000-04:00', 'date_ready_to_ship': '2023-12-10T23:26:49.470-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 36.81, 'priority_class': {'id': '30'}, 'service_id': 312255, 'shipping_items': [{'quantity': 1, 'dimensions_source': {'origin': 'similarity', 'id': 'MLB3883007198__1'}, 'description': 'Pandeiro Pandeirola  Meia Lua Liverpool Amarelo Pml001am', 'id': 'MLB3883007198', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '7.0x23.0x38.0,600.0'}], 'tracking_number': '42893481001', 'cost_components': {'loyal_discount': 0.15, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 0}, 'id': 42893481001, 'tracking_method': None, 'last_updated': '2023-12-11T17:59:28.787-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-10T23:26:05.540-04:00', 'date_first_printed': '2023-12-10T23:26:57.709-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': None, 'cost': 13.52, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 512746, 'estimated_delivery_final': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 480}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 13.52, 'estimated_delivery_limit': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 72}, 'priority_class': {'id': '30'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': '2023-12-11T00:00:00.000-03:00'}, 'estimated_delivery_time': {'date': '2023-12-11T00:00:00.000-03:00', 'pay_before': '2023-12-11T13:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 0, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario a domicilio', 'id': 1574405210, 'estimated_delivery_extended': {'date': '2023-12-11T00:00:00.000-03:00', 'offset': 72}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRP2336324761', 'self_service_partner'], 'scoring': None, 'agency': None, 'city': {'id': 'BR-SP-44', 'name': 'São Paulo'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Conjunto Habitacional Santa Etelvina II'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua Croata 774', 'types': ['default_buying_address', 'default_return_address', 'shipping'], 'scoring': 4.9, 'agency': None, 'city': {'id': 'BR-SP-44', 'name': 'São Paulo'}, 'geolocation_type': 'ROOFTOP', 'latitude': -23.535041, 'municipality': {'id': None, 'name': None}, 'location_id': 617670, 'street_name': 'Rua Croata', 'zip ...
# 2023-12-12 22:21:49.517 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 2/508 (0.39%)
# 2023-12-12 22:21:50.592 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893614628: {'substatus_history': [{'date': '2023-12-10T23:31:24.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T22:46:09.772-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-12T00:42:41.699-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-12T01:02:33.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'a461a027-575d-448f-9211-fe30738220ad', 'pack_hash': '1'}, 'receiver_id': 158890583, 'base_cost': 27.1, 'status_history': {'date_shipped': '2023-12-12T01:47:19.186-04:00', 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-10T23:31:24.000-04:00', 'date_ready_to_ship': '2023-12-10T23:31:24.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 224.2, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB2171831134-174246496744'}, 'description': 'Ukulele Concert Acústico Tagima Natural Mahogany Satin 23k', 'id': 'MLB2171831134', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '9.0x25.0x63.0,730.0'}], 'tracking_number': 'MEL42893614628LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 50.05}, 'id': 42893614628, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T17:57:08.553-04:00', 'items_types': ['new'], 'comments': None, 'substatus': 'out_for_delivery', 'date_created': '2023-12-10T23:31:19.864-04:00', 'date_first_printed': '2023-12-12T00:42:40.697-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 180, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 507946, 'estimated_delivery_final': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 22.95, 'estimated_delivery_limit': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-13T00:00:00.000-03:00', 'pay_before': '2023-12-12T00:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 48, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario', 'id': 1175638385, 'estimated_delivery_extended': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRBA01', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'TUxCQ0xBVTE2OWRi', 'name': 'Lauro de Freitas'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-BA', 'name': 'Bahia'}, 'neighborhood': {'id': None, 'name': 'Barro Duro'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua São Salvador 126', 'types': ['default_buying_address'], 'scoring': 4.37, 'agency': None, 'city ...
# 2023-12-12 22:21:50.596 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 3/508 (0.59%)
# 2023-12-12 22:21:51.661 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893525733: {'substatus_history': [{'date': '2023-12-10T23:47:01.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T16:12:43.707-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T19:15:35.398-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T20:39:01.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}, {'date': '2023-12-12T08:46:49.138-04:00', 'substatus': 'waiting_for_withdrawal', 'status': 'shipped'}], 'snapshot_packing': {'snapshot_id': '492455a4-334c-42a2-8d3c-773112fde544', 'pack_hash': '1'}, 'receiver_id': 26422464, 'base_cost': 25.9, 'status_history': {'date_shipped': '2023-12-11T22:48:04.000-04:00', 'date_returned': None, 'date_delivered': None, 'date_first_visit': '2023-12-12T08:46:49.138-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-10T23:47:01.000-04:00', 'date_ready_to_ship': '2023-12-10T23:47:01.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 249.9, 'priority_class': {'id': '10'}, 'service_id': 255682, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'optimal_box', 'id': None}, 'description': 'Escaleta Profissional 37 Teclas Com Case Preta Dolphin Cor Preto', 'id': 'MLB3415515115', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '17.0x61.0x24.0,1570.0'}], 'tracking_number': 'MEL42893525733LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 49.85}, 'id': 42893525733, 'tracking_method': 'Agências Mercado Livre', 'last_updated': '2023-12-12T08:46:52.110-04:00', 'items_types': ['new'], 'comments': None, 'substatus': 'waiting_for_withdrawal', 'date_created': '2023-12-10T23:46:57.420-04:00', 'date_first_printed': '2023-12-11T19:15:34.123-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 720, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 512146, 'estimated_delivery_final': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 23.95, 'estimated_delivery_limit': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-12T00:00:00.000-03:00', 'pay_before': '2023-12-11T23:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 24, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Retiro Prioritario na agência', 'id': 1534150828, 'estimated_delivery_extended': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP10', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlJGcmFuY28gZGEgUm9jaGE', 'name': 'Franco da Rocha'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Parque Santa Delfa'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address' ...
# 2023-12-12 22:21:51.664 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 4/508 (0.79%)
# 2023-12-12 22:21:52.675 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893659026: {'substatus_history': [{'date': '2023-12-10T23:52:51.000-04:00', 'substatus': 'invoice_pending', 'status': 'ready_to_ship'}, {'date': '2023-12-11T11:07:36.512-04:00', 'substatus': 'waiting_for_carrier_authorization', 'status': 'ready_to_ship'}, {'date': '2023-12-11T11:07:37.774-04:00', 'substatus': 'ready_to_print', 'status': 'ready_to_ship'}, {'date': '2023-12-11T16:13:53.000-04:00', 'substatus': 'picked_up', 'status': 'ready_to_ship'}, {'date': '2023-12-11T18:56:30.000-04:00', 'substatus': 'in_hub', 'status': 'ready_to_ship'}, {'date': '2023-12-11T18:56:32.171-04:00', 'substatus': 'authorized_by_carrier', 'status': 'ready_to_ship'}, {'date': '2023-12-11T20:31:27.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'd32a15ef-ec48-4ab0-afe9-226062eed3ff', 'pack_hash': '1'}, 'receiver_id': 594126104, 'base_cost': 34.1, 'status_history': {'date_shipped': '2023-12-12T03:16:15.663-04:00', 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-10T23:52:51.000-04:00', 'date_ready_to_ship': '2023-12-10T23:52:51.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 403.66, 'priority_class': {'id': '20'}, 'service_id': 508360, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'dimensions_sorter_conciliation', 'id': 'MLB2161169841__1'}, 'description': 'Violao Infantil Capital América De Madeira Profissional Phx', 'id': 'MLB2161169841', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '10.0x34.0x81.0,1447.0'}], 'tracking_number': 'MEL42893659026LMXDF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 10.15, 'ratio': 47.9}, 'id': 42893659026, 'tracking_method': 'MEL Voluminoso', 'last_updated': '2023-12-12T03:16:18.953-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-10T23:52:42.824-04:00', 'date_first_printed': '2023-12-11T11:07:39.584-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': None, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 100009, 'estimated_delivery_final': {'date': '2023-12-14T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 23.95, 'estimated_delivery_limit': {'date': '2023-12-14T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '20'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': '2023-12-11T00:00:00.000-03:00'}, 'estimated_delivery_time': {'date': '2023-12-14T00:00:00.000-03:00', 'pay_before': '2023-12-11T15:22:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': '2023-12-15T00:00:00.000-03:00', 'shipping': 24}, 'shipping': 72, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known_frame'}, 'name': 'Normal', 'id': 2933278845, 'estimated_delivery_extended': {'date': '2023-12-14T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['default_return_address', 'shipping'], 'scoring': 3.34, 'agency': None, 'city': {'id': 'BR-SP-44', 'name': 'São Paulo'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': 516323, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': 'geolocation-feedback', 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': 1316706177, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Conjunto Habitacional Santa Etelvina II'}, 'geolocation_last_upd ...
# 2023-12-12 22:21:52.678 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 5/508 (0.98%)
# 2023-12-12 22:21:53.712 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893696810: {'substatus_history': [{'date': '2023-12-11T00:13:40.820-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-11T00:14:22.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T11:14:31.668-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T13:26:30.316-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T13:35:27.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'b492c96b-80e4-4de0-82aa-1edac565a3b7', 'pack_hash': '1'}, 'receiver_id': 17720605, 'base_cost': 0, 'status_history': {'date_shipped': '2023-12-11T15:43:28.225-04:00', 'date_returned': None, 'date_delivered': '2023-12-12T11:52:43.000-04:00', 'date_first_visit': '2023-12-12T11:52:43.000-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T00:14:22.000-04:00', 'date_ready_to_ship': '2023-12-11T00:14:22.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 186.6, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3461876520__1'}, 'description': 'Encordoamento Sg Cordas 009 Para Guitarra - Kit Com 3 Jogos', 'id': 'MLB3461876520', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '10.0x19.0x16.0,920.0'}], 'tracking_number': 'MEL42893696810LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 21.6, 'ratio': 0}, 'id': 42893696810, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T11:52:45.248-04:00', 'items_types': ['fragile', 'new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T00:13:39.991-04:00', 'date_first_printed': '2023-12-11T13:26:17.172-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 210, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 182, 'estimated_delivery_final': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 0, 'estimated_delivery_limit': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-12T00:00:00.000-03:00', 'pay_before': '2023-12-11T18:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': '2023-12-13T00:00:00.000-03:00', 'shipping': 24}, 'shipping': 24, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known_frame'}, 'name': 'Expresso', 'id': 147839055, 'estimated_delivery_extended': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSC02', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'TUxCQ0dPVjUyMzEx', 'name': 'Governador Celso Ramos'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': None, 'state': {'id': 'BR-SC', 'name': 'Santa Catarina'}, 'neighborhood': {'id': None, 'name': 'Guaporanga'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'coun ...
# 2023-12-12 22:21:53.715 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 6/508 (1.18%)
# 2023-12-12 22:21:54.891 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893749984: {'substatus_history': [{'date': '2023-12-11T00:47:41.344-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-11T00:48:26.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-12T18:22:51.651-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-12T18:57:16.503-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-12T19:01:59.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': '5cf23aa5-5647-40f6-a366-8e4886539f85', 'pack_hash': '1'}, 'receiver_id': 145101555, 'base_cost': 81.9, 'status_history': {'date_shipped': None, 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T00:48:26.000-04:00', 'date_ready_to_ship': '2023-12-11T00:48:26.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 518.31, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB4102571454__1'}, 'description': 'Cabo Em Rolo Para Microfone 0,30mm Modelo Sc30  Santo Angelo', 'id': 'MLB4102571454', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '11.0x34.0x36.0,5290.0'}], 'tracking_number': 'MEL42893749984LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 80.85}, 'id': 42893749984, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T19:02:00.099-04:00', 'items_types': ['new'], 'comments': None, 'substatus': 'in_packing_list', 'date_created': '2023-12-11T00:47:40.695-04:00', 'date_first_printed': '2023-12-12T18:57:15.188-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 150, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 512946, 'estimated_delivery_final': {'date': '2023-12-16T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': '2023-12-12T00:00:00.000Z'}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 40.95, 'estimated_delivery_limit': {'date': '2023-12-16T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-16T00:00:00.000-03:00', 'pay_before': '2023-12-12T23:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 120, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario', 'id': 3810262761, 'estimated_delivery_extended': {'date': '2023-12-16T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP04', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Paineira (Jordanésia)'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua Quintino Bo ...
# 2023-12-12 22:21:54.894 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 7/508 (1.38%)
# 2023-12-12 22:21:55.917 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893820024: {'substatus_history': [{'date': '2023-12-11T01:47:58.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T04:52:36.802-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T05:21:42.410-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T05:34:02.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': 'f98f1b81-1b28-4af0-a61a-e2814a3d32aa', 'pack_hash': '1'}, 'receiver_id': 1463648060, 'base_cost': 24.6, 'status_history': {'date_shipped': '2023-12-11T17:34:05.949-04:00', 'date_returned': None, 'date_delivered': '2023-12-12T10:47:35.000-04:00', 'date_first_visit': '2023-12-12T10:47:35.000-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T01:47:58.000-04:00', 'date_ready_to_ship': '2023-12-11T01:47:58.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 219.91, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3860760526__1'}, 'description': 'Escaleta Profissional Dolphin 32 Teclas C/ Case E Acessórios Cor Preto', 'id': 'MLB3860760526', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '6.0x20.0x49.0,1150.0'}], 'tracking_number': 'MEL42893820024LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 47.05}, 'id': 42893820024, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T10:47:36.323-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T01:46:55.222-04:00', 'date_first_printed': '2023-12-11T05:21:41.240-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 150, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 507945, 'estimated_delivery_final': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 22.45, 'estimated_delivery_limit': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-12T00:00:00.000-03:00', 'pay_before': '2023-12-12T00:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 24, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario', 'id': 2796522006, 'estimated_delivery_extended': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP02', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Colina'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua Siqueira Campos 138', 'types': ['def ...
# 2023-12-12 22:21:55.920 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 8/508 (1.57%)
# 2023-12-12 22:21:56.916 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893846638: {'substatus_history': [{'date': '2023-12-11T02:18:15.497-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-11T02:19:01.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T21:15:37.897-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T22:02:28.220-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T22:15:34.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': '2720ce65-9536-442c-88d7-e6b80e45cca9', 'pack_hash': '3'}, 'receiver_id': 1064136362, 'base_cost': 0, 'status_history': {'date_shipped': '2023-12-12T01:46:27.000-04:00', 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T02:19:01.000-04:00', 'date_ready_to_ship': '2023-12-11T02:19:01.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 119.8, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'quantity': 2, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3829652726__1'}, 'description': 'Cabo Santo Angelo Ninja 4,57m P10 Reto Guitarra Violão Baixo', 'id': 'MLB3829652726', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '6.0x12.0x26.0,600.0'}], 'tracking_number': 'MEL42893846638LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 21.5}, 'id': 42893846638, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T01:46:45.113-04:00', 'items_types': ['fragile', 'new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T02:18:14.720-04:00', 'date_first_printed': '2023-12-11T22:02:27.328-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 210, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 507946, 'estimated_delivery_final': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 0, 'estimated_delivery_limit': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-13T00:00:00.000-03:00', 'pay_before': '2023-12-11T23:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 48, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario', 'id': 1910526506, 'estimated_delivery_extended': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRBA01', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'TUxCQ0xBVTE2OWRi', 'name': 'Lauro de Freitas'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-BA', 'name': 'Bahia'}, 'neighborhood': {'id': None, 'name': 'Barro Duro'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua Circular 153', 'types': ['default_buy ...
# 2023-12-12 22:21:56.918 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 9/508 (1.77%)
# 2023-12-12 22:21:57.895 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42893885832: {'substatus_history': [{'date': '2023-12-11T03:36:26.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T16:08:44.000-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-11T19:57:12.147-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-11T20:08:08.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}, {'date': '2023-12-12T12:26:00.556-04:00', 'substatus': 'waiting_for_withdrawal', 'status': 'shipped'}], 'snapshot_packing': {'snapshot_id': 'a35286b4-f878-49de-ad1c-3a19e63892a1', 'pack_hash': '1'}, 'receiver_id': 326449907, 'base_cost': 9.2, 'status_history': {'date_shipped': '2023-12-11T23:56:11.000-04:00', 'date_returned': None, 'date_delivered': None, 'date_first_visit': '2023-12-12T12:26:00.556-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T03:36:26.000-04:00', 'date_ready_to_ship': '2023-12-11T03:36:26.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 21.9, 'priority_class': {'id': '30'}, 'service_id': 255682, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB1992567302-173585284763'}, 'description': '1 Par Baquetas De Bateria Liverpool Nirvana 5a Ou 5b Ou 7a', 'id': 'MLB1992567302', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '3.0x3.0x39.0,110.0'}], 'tracking_number': 'MEL42893885832LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 0}, 'id': 42893885832, 'tracking_method': 'Agências Mercado Livre', 'last_updated': '2023-12-12T12:26:01.592-04:00', 'items_types': ['new'], 'comments': None, 'substatus': 'waiting_for_withdrawal', 'date_created': '2023-12-11T03:35:22.059-04:00', 'date_first_printed': '2023-12-11T19:57:10.636-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 150, 'cost': 9.2, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 512146, 'estimated_delivery_final': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 9.2, 'estimated_delivery_limit': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '30'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-12T00:00:00.000-03:00', 'pay_before': '2023-12-11T22:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 24, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Retiro Prioritario na agência', 'id': 2326559444, 'estimated_delivery_extended': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP04', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': None, 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': None, 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Paineira (Jordanésia)'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receive ...
# 2023-12-12 22:21:57.899 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 10/508 (1.97%)
# ...
# 2023-12-12 22:24:17.815 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 134/508 (26.38%)
# 2023-12-12 22:24:19.259 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42895671639: {'substatus_history': [{'date': '2023-12-11T14:13:55.076-04:00', 'substatus': 'shipment_paid', 'status': 'pending'}, {'date': '2023-12-11T14:14:51.000-04:00', 'substatus': 'in_warehouse', 'status': 'ready_to_ship'}, {'date': '2023-12-11T21:29:21.348-04:00', 'substatus': 'ready_to_pack', 'status': 'ready_to_ship'}, {'date': '2023-12-12T06:46:38.396-04:00', 'substatus': 'packed', 'status': 'ready_to_ship'}, {'date': '2023-12-12T06:51:12.000-04:00', 'substatus': 'in_packing_list', 'status': 'ready_to_ship'}], 'snapshot_packing': {'snapshot_id': '1d7f4891-513e-4863-933a-4cf877aac311', 'pack_hash': '1'}, 'receiver_id': 135402588, 'base_cost': 0, 'status_history': {'date_shipped': '2023-12-12T12:51:13.173-04:00', 'date_returned': None, 'date_delivered': None, 'date_first_visit': None, 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T14:14:51.000-04:00', 'date_ready_to_ship': '2023-12-11T14:14:51.000-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 519.75, 'priority_class': {'id': '10'}, 'service_id': 157861, 'shipping_items': [{'quantity': 2, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB3780803056__1'}, 'description': 'Correia Guitarra Violão Baixo Alça Basso Cla09 Couro Marrom', 'id': 'MLB3780803056', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '23.0x29.0x36.0,1375.0'}], 'tracking_number': 'MEL42895671639LMFFF01', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0.2, 'ratio': 84.8}, 'id': 42895671639, 'tracking_method': 'MEL Distribution', 'last_updated': '2023-12-12T12:51:14.634-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T14:13:53.920-04:00', 'date_first_printed': '2023-12-12T06:46:35.225-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 210, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 515364, 'estimated_delivery_final': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 720}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 0, 'estimated_delivery_limit': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'priority_class': {'id': '10'}, 'delivery_promise': 'accurate', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': None}, 'estimated_delivery_time': {'date': '2023-12-13T00:00:00.000-03:00', 'pay_before': '2023-12-12T10:30:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 24, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Estándar a domicilio', 'id': 1515531267, 'estimated_delivery_extended': {'date': '2023-12-13T00:00:00.000-03:00', 'offset': 480}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRSP02', 'warehouse'], 'scoring': None, 'agency': None, 'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Empresarial Colina'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua José Sebastião de Almeid ...
# 2023-12-12 22:24:19.263 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 135/508 (26.57%)
# 2023-12-12 22:24:20.552 | INFO     | __main__:get_orders_for_date_range:184 - Obtido com sucesso para shipping_id 42895682023: {'substatus_history': [], 'snapshot_packing': {'snapshot_id': '4b57205e-f929-49e4-aca2-4d9cf238b453', 'pack_hash': '1'}, 'receiver_id': 241671584, 'base_cost': 15.9, 'status_history': {'date_shipped': '2023-12-12T15:44:38.096-04:00', 'date_returned': None, 'date_delivered': '2023-12-12T17:54:39.310-04:00', 'date_first_visit': '2023-12-12T17:54:39.310-04:00', 'date_not_delivered': None, 'date_cancelled': None, 'date_handling': '2023-12-11T14:16:16.000-04:00', 'date_ready_to_ship': '2023-12-11T14:16:17.480-04:00'}, 'type': 'forward', 'return_details': None, 'sender_id': 233632476, 'mode': 'me2', 'order_cost': 224.2, 'priority_class': {'id': '10'}, 'service_id': 312255, 'shipping_items': [{'domain_id': None, 'quantity': 1, 'dimensions_source': {'origin': 'fulfillment', 'id': 'MLB2171831134-174246496744'}, 'description': 'Ukulele Concert Acústico Tagima Natural Mahogany Satin 23k', 'id': 'MLB2171831134', 'user_product_id': None, 'sender_id': 233632476, 'dimensions': '9.0x25.0x63.0,730.0'}], 'tracking_number': '42895682023', 'cost_components': {'loyal_discount': 0, 'special_discount': 0, 'compensation': 0, 'gap_discount': 0, 'ratio': 30.21}, 'id': 42895682023, 'tracking_method': None, 'last_updated': '2023-12-12T17:54:42.328-04:00', 'items_types': ['new'], 'comments': None, 'substatus': None, 'date_created': '2023-12-11T14:16:09.055-04:00', 'date_first_printed': '2023-12-11T14:16:24.624-04:00', 'created_by': 'receiver', 'application_id': None, 'shipping_option': {'processing_time': 720, 'cost': 0, 'estimated_schedule_limit': {'date': None}, 'shipping_method_id': 507945, 'estimated_delivery_final': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 480}, 'buffering': {'date': None}, 'pickup_promise': {'from': None, 'to': None}, 'list_cost': 14.31, 'estimated_delivery_limit': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 72}, 'priority_class': {'id': '10'}, 'delivery_promise': 'estimated', 'delivery_type': 'estimated', 'estimated_handling_limit': {'date': '2023-12-12T00:00:00.000-03:00'}, 'estimated_delivery_time': {'date': '2023-12-12T00:00:00.000-03:00', 'pay_before': '2023-12-12T13:00:00.000-03:00', 'schedule': None, 'unit': 'hour', 'offset': {'date': None, 'shipping': None}, 'shipping': 0, 'time_frame': {'from': None, 'to': None}, 'handling': 0, 'type': 'known'}, 'name': 'Prioritario', 'id': 3675589450, 'estimated_delivery_extended': {'date': '2023-12-12T00:00:00.000-03:00', 'offset': 72}, 'currency_id': 'BRL'}, 'tags': [], 'sender_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'XXXXXXX', 'types': ['logistic_center_BRP2336324761', 'self_service_partner'], 'scoring': None, 'agency': None, 'city': {'id': 'BR-SP-44', 'name': 'São Paulo'}, 'geolocation_type': 'ROOFTOP', 'latitude': 0, 'municipality': {'id': None, 'name': None}, 'location_id': None, 'street_name': 'XXXXXXX', 'zip_code': 'XXXXXXX', 'geolocation_source': None, 'intersection': None, 'street_number': 'XXXXXXX', 'comment': 'XXXXXXX', 'id': None, 'state': {'id': 'BR-SP', 'name': 'São Paulo'}, 'neighborhood': {'id': None, 'name': 'Conjunto Habitacional Santa Etelvina II'}, 'geolocation_last_updated': None, 'longitude': 0}, 'sibling': {'reason': None, 'sibling_id': None, 'description': None, 'source': None, 'date_created': None, 'last_updated': None}, 'return_tracking_number': None, 'site_id': 'MLB', 'carrier_info': None, 'market_place': 'MELI', 'receiver_address': {'country': {'id': 'BR', 'name': 'Brasil'}, 'address_line': 'Rua Juruá 328', 'types': ['billing', 'default_buying_address', 'default_return_address', 'default_selling_address', 'shipping'], 'scoring': 4.28, 'agency': None, 'city': {'id': 'BR-SP-45', 'name': 'Cotia'}, 'geolocation_type': 'ROOFTOP', 'latitude': -23.574088, 'municipality': {'id': None, 'name': None}, 'location_id': 811556, 'street_name': 'Rua Juruá', 'zip_code': '06704762', 'geolocation_source': ' ...
# 2023-12-12 22:24:20.555 | INFO     | __main__:get_orders_for_date_range:192 - Progresso: 136/508 (26.77%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_orders_for_date_range(ACCESS_TOKEN_MCENTER, SELLER_ID_MCENTER, today_str, tomorrow_str, 'mcenter_ot')
#
# Cell In[3], line 178, in get_orders_for_date_range(access_token, seller_id, date_from, date_to, table_orders, offset, limit)
#     175 headers = {"Authorization": f"Bearer {access_token}"}
#     177 try:
# --> 178     response = requests.get(url, headers=headers)
#     179     response.raise_for_status()
#     181     json_data = response.json()
#
# File c:\Users\couti\projetos\mcenter_streamlit\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\couti\projetos\mcenter_streamlit\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\couti\projetos\mcenter_streamlit\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\couti\projetos\mcenter_streamlit\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\couti\projetos\mcenter_streamlit\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\couti\projetos\mcenter_streamlit\venv\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\couti\projetos\mcenter_streamlit\venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\couti\projetos\mcenter_streamlit\venv\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1411, in HTTPConnection.getresponse(self)
#    1409 try:
#    1410     try:
# -> 1411         response.begin()
#    1412     except ConnectionError:
#    1413         self.close()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:324, in HTTPResponse.begin(self)
#     322 # read until we get a non-100 response
#     323 while True:
# --> 324     version, status, reason = self._read_status()
#     325     if status != CONTINUE:
#     326         break
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:285, in HTTPResponse._read_status(self)
#     284 def _read_status(self):
# --> 285     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     286     if len(line) > _MAXLINE:
#     287         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1249, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1245     if flags != 0:
#    1246         raise ValueError(
#    1247           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1248           self.__class__)
# -> 1249     return self.read(nbytes, buffer)
#    1250 else:
#    1251     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:
