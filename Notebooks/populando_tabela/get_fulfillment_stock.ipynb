# %%
import json
import os
import time
from datetime import datetime
from loguru import logger

import numpy as np
import pandas as pd
import psycopg2
import requests
from dotenv import load_dotenv
from pandas import json_normalize
from psycopg2 import sql

# %%
load_dotenv()

ACCESS_TOKEN_BUENOSHOPS = os.getenv("ACCESS_TOKEN_BUENOSHOPS")
ACCESS_TOKEN_MUSICALCRIS = os.getenv("ACCESS_TOKEN_MUSICALCRIS")
ACCESS_TOKEN_MCENTER = os.getenv("ACCESS_TOKEN_MCENTER")

HOST = os.getenv("HOST")
POSTGRES_DB = os.getenv("POSTGRES_DB")
POSTGRES_USER = os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")


# Informações de conexão com o banco de dados PostgreSQL
db_config = {
    "host": HOST,
    "database": POSTGRES_DB,
    "user": POSTGRES_USER,
    "password": POSTGRES_PASSWORD,
}

# %%
def get_fulfillment_stock(access_token, db_config, table_item, table_fulfillment):
    logger.add(
        f"Data/Output/Log/{table_fulfillment}.log",
        rotation="10 MB",
        format="{time:YYYY-MM-DD at HH:mm:ss} | {level} | {message}",
    )

    # Informações de conexão com o banco de dados PostgreSQL
    conn = psycopg2.connect(**db_config)

    sql_query = f"SELECT * FROM {table_item}"
    logger.info(sql_query)

    df_codes = pd.read_sql(sql_query, conn)

    # df_codes = df_codes.sample(10)

    # Verifica se há duplicatas
    duplicates = df_codes.duplicated()
    n_dup = duplicates.sum()

    logger.info(f"Número de duplicatas: {n_dup}")

    # Encontre as duplicatas no DataFrame
    duplicates = df_codes[df_codes.duplicated(keep=False)]

    # Remove as duplicatas e atualiza o DataFrame
    df_codes = df_codes.drop_duplicates()

    # ### Pegando Estoque de FulFillment

    # removendo valores nulos
    df_codes = df_codes.dropna(subset=["inventory_id"])
    # df_codes["inventory_id"].value_counts()

    # removendo valores nulos
    df_variations = df_codes.dropna(subset=["variation_id"])
    # df_variations["variation_id"].value_counts()

    var_codes = df_codes["variation_id"].unique()
    codes = df_codes["inventory_id"].unique()

    codes = np.delete(codes, np.where(codes == "NaN"))
    var_codes = np.delete(var_codes, np.where(var_codes == "NaN"))

    # unique_values = set(codes)
    # num_unique_values = len(unique_values)

    unique_values = set(codes)
    num_unique_values = len(unique_values)

    logger.info(f"Quantidade de valores únicos: {num_unique_values}")

    counter = 0
    json_list = []

    for item in codes:
        url = f"https://api.mercadolibre.com/inventories/{item}/stock/fulfillment"

        payload = {}
        headers = {"Authorization": f"Bearer {access_token}"}
        logger.info(f"Buscando dados {counter}/{len(codes)}: {item}")

        try:
            response = requests.get(url, headers=headers, data=payload)
            response.raise_for_status()  # Lança uma exceção HTTPError para códigos de status de erro
            response_data = response.json()
            json_list.append(response_data)
            counter += 1

            if counter % 50 == 0:
                logger.warning(f"Fazendo uma pausa de 1 minuto...")
                time.sleep(60)

        except requests.exceptions.RequestException as e:
            logger.error(f"Erro ao fazer a requisição para {url}: {e}")

        except Exception as e:
            logger.error(f"Erro não esperado: {e}")

    file_path = f"Data/Output/list_{table_fulfillment}.json"
    with open(file_path, "w") as file:
        json.dump(json_list, file)

    print(json_list)

    resultados = []

    for item in json_list:
        # Extrair os valores desejados
        inventory_id = item["inventory_id"]
        total = item["total"]
        available_quantity = item["available_quantity"]
        not_available_quantity = item["not_available_quantity"]
        not_available_detail = item.get(
            "not_available_detail", []
        )  # Evita KeyError se "not_available_detail" estiver ausente
        external_references = item.get("external_references", [])

        # Inicializa variáveis para armazenar detalhes
        not_available_detail_status = None
        not_available_detail_quantity = None
        external_references_type = None
        external_references_id = None
        external_references_variation_id = None

        # Verifica se há pelo menos um item em "not_available_detail"
        if not_available_detail:
            not_available_detail_status = not_available_detail[0].get("status")
            not_available_detail_quantity = not_available_detail[0].get("quantity")

        if external_references:
            external_references_type = external_references[0].get("type")
            external_references_id = external_references[0].get("id")
            external_references_variation_id = external_references[0].get(
                "variation_id"
            )

        # Adicionar os resultados à lista
        resultados.append(
            {
                "inventory_id": inventory_id,
                "total": total,
                "available_quantity": available_quantity,
                "not_available_quantity": not_available_quantity,
                # "not_available_detail": not_available_detail,
                # "external_references": external_references,
                "not_available_detail_status": not_available_detail_status,
                "not_available_detail_quantity": not_available_detail_quantity,
                "external_references_type": external_references_type,
                "external_references_id": external_references_id,
                "external_references_variation_id": external_references_variation_id,
            }
        )

    # Exibir os resultados
    df = pd.DataFrame(resultados)

    # df['external_references_variation_id'].astype(str).apply(lambda x:x.rstrip('.0'))
    df["external_references_variation_id"] = (
        df["external_references_variation_id"]
        .astype(str)
        .apply(lambda x: x.rstrip(".0"))
    )

    df["not_available_detail_quantity"] = pd.to_numeric(
        df["not_available_detail_quantity"], errors="coerce"
    ).astype("Int64")
    df["not_available_detail_status"] = df["not_available_detail_status"].astype(str)
    df["external_references_id"] = df["external_references_id"].astype(str)

    conn = psycopg2.connect(**db_config)
    cursor = conn.cursor()

    for index, row in df.iterrows():
        # Substituir valores NaN por None
        row = row.apply(lambda x: None if pd.isna(x) else x)

        current_time = datetime.now()
        query = f"""
                INSERT INTO {table_fulfillment} (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
                VALUES (%s, %s, %s, %s, %s, %s, %s)
            """
        insert_query = sql.SQL(query)
        logger.info(query)
        cursor.execute(
            insert_query,
            (
                row["inventory_id"],
                row["available_quantity"],
                row["not_available_detail_status"],
                row["not_available_detail_quantity"],
                row["external_references_id"],
                row["external_references_variation_id"],
                current_time,
            ),
        )

    conn.commit()

    cursor.close()
    conn.close()

    logger.info("Dados inseridos com sucesso!")

# %%
get_fulfillment_stock(ACCESS_TOKEN_BUENOSHOPS, db_config, "bueno_items", "bueno_ft")
# Out:
# 2023-12-12 21:00:42.987 | INFO     | __main__:get_fulfillment_stock:13 - SELECT * FROM bueno_items
# C:\Users\couti\AppData\Local\Temp\ipykernel_8832\1089758525.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_codes = pd.read_sql(sql_query, conn)
# 2023-12-12 21:00:43.056 | INFO     | __main__:get_fulfillment_stock:24 - Número de duplicatas: 0
# 2023-12-12 21:00:43.074 | INFO     | __main__:get_fulfillment_stock:55 - Quantidade de valores únicos: 234
# 2023-12-12 21:00:43.078 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados
available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB1943179894'}]}, {'inventory_id': 'EPJU71741', 'total': 16, 'available_quantity': 15, 'not_available_quantity': 1, 'not_available_detail': [{'status': 'transfer', 'quantity': 1}], 'external_references': [{'type': 'item', 'id': 'MLB2193833161'}]}, {'inventory_id': 'EEQD73083', 'total': 82, 'available_quantity': 26, 'not_available_quantity': 56, 'not_available_detail': [{'status': 'noFiscalCoverage', 'quantity': 1}, {'status': 'transfer', 'quantity': 55}], 'external_references': [{'type': 'item', 'id': 'MLB2199852972', 'variation_id': 174286948918}]}, {'inventory_id': 'DEYX78460', 'total': 46, 'available_quantity': 41, 'not_available_quantity': 5, 'not_available_detail': [{'status': 'noFiscalCoverage', 'quantity': 1}, {'status': 'transfer', 'quantity': 4}], 'external_references': [{'type': 'item', 'id': 'MLB2199852972', 'variation_id': 174286660366}]}, {'inventory_id': 'WEVB83547', 'total': 43, 'available_quantity': 42, 'not_available_quantity': 1, 'not_available_detail': [{'status': 'noFiscalCoverage', 'quantity': 1}], 'external_references': [{'type': 'item', 'id': 'MLB2199852972', 'variation_id': 174286660367}]}, {'inventory_id': 'PJAQ71858', 'total': 5, 'available_quantity': 5, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB2212359816', 'variation_id': 176237667269}]}, {'inventory_id': 'ZBFF82877', 'total': 4, 'available_quantity': 4, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB2601815703'}]}, {'inventory_id': 'GBRE84489', 'total': 0, 'available_quantity': 0, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB2612142751'}]}, {'inventory_id': 'CZVM84616', 'total': 335, 'available_quantity': 326, 'not_available_quantity': 9, 'not_available_detail': [{'status': 'noFiscalCoverage', 'quantity': 1}, {'status': 'transfer', 'quantity': 8}], 'external_references': [{'type': 'item', 'id': 'MLB2614836456'}]}, {'inventory_id': 'DVPO87856', 'total': 1, 'available_quantity': 1, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB2618672341'}]}, {'inventory_id': 'LDJE87361', 'total': 2, 'available_quantity': 2, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB2618666963'}]}, {'inventory_id': 'VKTA87147', 'total': 3, 'available_quantity': 3, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB2619308046'}]}, {'inventory_id': 'LNUD88057', 'total': 0, 'available_quantity': 0, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB2621326191', 'variation_id': 174436021551}]}, {'inventory_id': 'AXXP93913', 'total': 9, 'available_quantity': 5, 'not_available_quantity': 4, 'not_available_detail': [{'status': 'noFiscalCoverage', 'quantity': 1}, {'status': 'transfer', 'quantity': 3}], 'external_references': [{'type': 'item', 'id': 'MLB2651935227', 'variation_id': 174549621597}]}, {'inventory_id': 'AGXO05820', 'total': 29, 'available_quantity': 28, 'not ...
# 2023-12-12 21:08:59.044 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.072 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.090 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.107 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.125 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.144 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.161 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.178 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.196 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.226 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.245 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.277 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.294 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.311 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.329 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.350 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.367 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.388 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.407 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.424 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.441 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.464 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.483 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.502 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.519 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.537 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.557 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.574 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.591 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.612 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.629 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.648 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.671 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.690 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.706 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.723 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.740 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.759 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.778 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.796 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.816 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.839 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.859 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.878 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.897 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.920 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.939 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.958 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.976 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:08:59.996 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.028 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.047 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.066 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.085 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.106 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.134 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.154 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.181 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.200 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.219 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:00.239 | INFO     | __main__:get_fulfillment_stock:172 -
# ...
#
# 2023-12-12 21:09:02.646 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.669 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.688 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.706 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.724 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.742 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.760 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.779 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.812 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.834 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.855 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.884 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.906 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.929 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.947 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.965 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:02.985 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.005 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.023 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.042 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.062 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.089 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.107 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.129 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.150 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.168 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.188 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.206 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.227 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.245 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.262 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.280 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.298 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.318 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.336 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.358 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.375 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.400 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.420 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.439 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.458 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.476 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.493 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.511 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.529 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.548 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.573 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.597 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.636 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.663 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.680 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.698 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.717 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO bueno_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:09:03.752 | INFO     | __main__:get_fulfillment_stock:191 - Dados inseridos com sucesso!

# %%
get_fulfillment_stock(ACCESS_TOKEN_MUSICALCRIS, db_config, "cris_items", "cris_ft")
# Out:
# 2023-12-12 21:09:03.901 | INFO     | __main__:get_fulfillment_stock:13 - SELECT * FROM cris_items
# C:\Users\couti\AppData\Local\Temp\ipykernel_8832\1089758525.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_codes = pd.read_sql(sql_query, conn)
# 2023-12-12 21:09:03.955 | INFO     | __main__:get_fulfillment_stock:24 - Número de duplicatas: 0
# 2023-12-12 21:09:03.966 | INFO     | __main__:get_fulfillment_stock:55 - Quantidade de valores únicos: 82
# 2023-12-12 21:09:03.970 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 0/82: KGZZ89270
# 2023-12-12 21:09:04.986 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 1/82: GOYP17092
# 2023-12-12 21:09:06.117 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 2/82: GXOM30321
# 2023-12-12 21:09:07.133 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 3/82: RWRR30846
# 2023-12-12 21:09:08.110 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 4/82: DGMW97350
# 2023-12-12 21:09:09.133 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 5/82: MMFT30494
# 2023-12-12 21:09:10.121 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 6/82: AEYS88396
# 2023-12-12 21:09:11.118 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 7/82: VAGV89301
# 2023-12-12 21:09:12.117 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 8/82: LLDE88401
# 2023-12-12 21:09:13.587 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 9/82: ACBX96049
# 2023-12-12 21:09:15.186 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 10/82: VHRN90158
# 2023-12-12 21:09:16.401 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 11/82: AKOJ90437
# 2023-12-12 21:09:17.412 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 12/82: FMUV90638
# 2023-12-12 21:09:18.392 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 13/82: SSIH91035
# 2023-12-12 21:09:19.389 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 14/82: NJXA90250
# 2023-12-12 21:09:20.385 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 15/82: OQSJ90492
# 2023-12-12 21:09:21.395 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 16/82: DGTO91061
# 2023-12-12 21:09:22.392 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 17/82: WGDP88625
# 2023-12-12 21:09:23.463 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados
| INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 67/82: VRME00762
# 2023-12-12 21:11:15.760 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 68/82: XQVO00216
# 2023-12-12 21:11:16.963 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 69/82: PFRK96451
# 2023-12-12 21:11:18.374 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 70/82: IVWT95612
# 2023-12-12 21:11:19.485 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 71/82: AYVG95677
# 2023-12-12 21:11:20.505 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 72/82: WUKX94837
# 2023-12-12 21:11:21.585 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 73/82: CMPE00886
# 2023-12-12 21:11:22.629 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 74/82: BIXC96031
# 2023-12-12 21:11:23.672 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 75/82: LKQN96991
# 2023-12-12 21:11:24.755 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 76/82: IFOR00903
# 2023-12-12 21:11:25.929 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 77/82: WXVN00727
# 2023-12-12 21:11:27.147 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 78/82: VLWK91331
# 2023-12-12 21:11:28.488 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 79/82: GZIL90714
# 2023-12-12 21:11:29.698 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 80/82: LDAC97015
# 2023-12-12 21:11:31.060 | INFO     | __main__:get_fulfillment_stock:66 - Buscando dados 81/82: WYGR96303
# [{'inventory_id': 'KGZZ89270', 'total': 2, 'available_quantity': 2, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB2077624899', 'variation_id': 173883881289}]}, {'inventory_id': 'GOYP17092', 'total': 1, 'available_quantity': 1, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB2077566813'}]}, {'inventory_id': 'GXOM30321', 'total': 2, 'available_quantity': 2, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3642965726'}]}, {'inventory_id': 'RWRR30846', 'total': 0, 'available_quantity': 0, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3321160629'}]}, {'inventory_id': 'DGMW97350', 'total': 1, 'available_quantity': 1, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3321186153'}]}, {'inventory_id': 'MMFT30494', 'total': 0, 'available_quantity': 0, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3321122477'}]}, {'inventory_id': 'AEYS88396', 'total': 8, 'available_quantity': 8, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3661055492'}]}, {'inventory_id': 'VAGV89301', 'total': 3, 'available_quantity': 3, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3661047876'}]}, {'inventory_id': 'LLDE88401', 'total': 0, 'available_quantity': 0, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB4097062232'}]}, {'inventory_id': 'ACBX96049', 'total': 1, 'available_quantity': 1, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB4099722814'}]}, {'inventory_id': 'VHRN90158', 'total': 0, 'available_quantity': 0, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB4099639536', 'variation_id': 180159251515}]}, {'inventory_id': 'AKOJ90437', 'total': 1, 'available_quantity': 1, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB4099564966'}]}, {'inventory_id': 'FMUV90638', 'total': 1, 'available_quantity': 1, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB4099421026'}]}, {'inventory_id': 'SSIH91035', 'total': 0, 'available_quantity': 0, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB4099400438'}]}, {'inventory_id': 'NJXA90250', 'total': 1, 'available_quantity': 1, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3468334819'}]}, {'inventory_id': 'OQSJ90492', 'total': 2, 'available_quantity': 2, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB4099364154'}]}, {'inventory_id': 'DGTO91061', 'total': 2, 'available_quantity': 2, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3468588713'}]}, {'inventory_id': 'WGDP88625', 'total': 1, 'available_quantity': 1, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3468571827'}]}, {'inventory_id': 'GNAY89939', 'total': 0, 'available_quantity': 0, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3468483295'}]}, {'inventory_id': 'CPRQ90376', 'total': 1, 'available_quantity': 1, 'not_available_quantity': 0, 'not_available_detail': [], 'external_references': [{'type': 'item', 'id': 'MLB3468355335'}]}, {'inventory_id': 'WCTG88354', 'total': 1, 'available_quantity': 1, 'not_available_quantity': 0, 'not_available_detail': ...
# 2023-12-12 21:11:32.794 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:32.822 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:32.842 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:32.863 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:32.880 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:32.899 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:32.919 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:32.958 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:32.982 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:32.999 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.028 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.085 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.103 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.128 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.154 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.173 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.192 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.212 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.232 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.256 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.272 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.290 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.309 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.328 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.349 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.372 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.391 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.408 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.432 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.452 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.478 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.509 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.534 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.556 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.583 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.605 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.639 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.667 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.688 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.714 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.735 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.760 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.791 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.815 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.839 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.861 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.885 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.916 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.944 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.967 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:33.986 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.006 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.025 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.052 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.070 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.090 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.110 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.131 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.199 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.222 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.247 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.268 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.296 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.318 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.354 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.382 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.400 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.420 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.439 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.458 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.477 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.499 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.518 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.544 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.562 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.582 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.603 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.626 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.644 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.662 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.682 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.703 | INFO     | __main__:get_fulfillment_stock:172 -
#                 INSERT INTO cris_ft (ml_inventory_id, available_quantity, detail_status, detail_quantity, references_id, references_variation_id, created_at)
#                 VALUES (%s, %s, %s, %s, %s, %s, %s)
#
# 2023-12-12 21:11:34.736 | INFO     | __main__:get_fulfillment_stock:191 - Dados inseridos com sucesso!

# %%
get_fulfillment_stock(ACCESS_TOKEN_MCENTER, db_config, "mcenter_items", "mcenter_ft")
